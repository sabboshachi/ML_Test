# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ML/updated/Titas_HistoricalPrices - Titas_HistoricalPrices.csv')

# %%
df
# Out:
#             Date   Open   High    Low  Close        Volume
# 0     2008-07-10  33.18  33.68  32.38  32.86  1.310925e+05
# 1     2008-07-14  32.16  32.16  30.74  31.13  8.604750e+04
# 2     2008-07-15  30.48  30.74  29.26  29.46  5.832750e+04
# 3     2008-07-16  28.23  28.33  27.27  27.32  1.911525e+05
# 4     2008-07-17  28.92  28.92  27.27  27.64  2.356200e+05
# ...          ...    ...    ...    ...    ...           ...
# 2669  2022-08-04  41.60  42.10  41.10  41.30  1.149216e+06
# 2670  2022-08-08  41.70  42.60  41.00  41.50  2.250486e+06
# 2671  2022-08-10  41.50  41.60  40.90  41.10  1.820146e+06
# 2672  2022-08-11  41.30  41.30  40.90  40.90  1.281802e+06
# 2673  2022-08-16  41.00  41.60  40.90  41.40  1.346727e+06
#
# [2674 rows x 6 columns]

# %%
df = df[['Date', 'Close']]
df.head(10)
# Out:
#          Date  Close
# 0  2008-07-10  32.86
# 1  2008-07-14  31.13
# 2  2008-07-15  29.46
# 3  2008-07-16  27.32
# 4  2008-07-17  27.64
# 5  2008-07-21  27.53
# 6  2008-07-22  27.60
# 7  2008-07-23  27.29
# 8  2008-07-24  27.25
# 9  2008-07-28  27.25

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('2008-07-28')
datetime_object
# Out:
# datetime.datetime(2008, 7, 28, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Date']
# Out:
# 0      2008-07-10
# 1      2008-07-14
# 2      2008-07-15
# 3      2008-07-16
# 4      2008-07-17
#           ...
# 2669   2022-08-04
# 2670   2022-08-08
# 2671   2022-08-10
# 2672   2022-08-11
# 2673   2022-08-16
# Name: Date, Length: 2674, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')

# %%
df.index
# Out:
# DatetimeIndex(['2008-07-10', '2008-07-14', '2008-07-15', '2008-07-16',
#                '2008-07-17', '2008-07-21', '2008-07-22', '2008-07-23',
#                '2008-07-24', '2008-07-28',
#                ...
#                '2022-07-27', '2022-07-28', '2022-08-01', '2022-08-02',
#                '2022-08-03', '2022-08-04', '2022-08-08', '2022-08-10',
#                '2022-08-11', '2022-08-16'],
#               dtype='datetime64[ns]', name='Date', length=2674, freq=None)

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  #print(target_date)
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+2)
    #print(df_subset)
    
    if len(df_subset) != n+2:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=100)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n+1):
    X[:, i]
    ret_df[f'Target-{n+1-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# %%
# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '2008-07-28', 
                                '2022-08-11',                         
                                n=5)
windowed_df
# Out:
#      Target Date  Target-6  Target-5  Target-4  Target-3  Target-2  Target-1  \
# 0     2008-07-28     27.32     27.64     27.53     27.60     27.29     27.25
# 1     2008-07-29     27.64     27.53     27.60     27.29     27.25     27.25
# 2     2008-07-30     27.53     27.60     27.29     27.25     27.25     27.25
# 3     2008-07-31     27.60     27.29     27.25     27.25     27.25     26.67
# 4     2008-08-04     27.29     27.25     27.25     27.25     26.67     26.13
# ...          ...       ...       ...       ...       ...       ...       ...
# 2659  2022-08-03     41.90     41.20     40.40     39.60     41.20     42.20
# 2660  2022-08-04     41.20     40.40     39.60     41.20     42.20     41.80
# 2661  2022-08-08     40.40     39.60     41.20     42.20     41.80     41.30
# 2662  2022-08-10     39.60     41.20     42.20     41.80     41.30     41.50
# 2663  2022-08-11     41.20     42.20     41.80     41.30     41.50     41.10
#
#       Target
# 0      27.25
# 1      27.25
# 2      26.67
# 3      26.13
# 4      25.02
# ...      ...
# 2659   41.80
# 2660   41.30
# 2661   41.50
# 2662   41.10
# 2663   40.90
#
# [2664 rows x 8 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((2664,), (2664, 6, 1), (2664,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90,]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((6, 1)),
                    layers.LSTM(128),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', optimizer=Adam(learning_rate=0.001), metrics=['mean_absolute_error'])

# model.compile(
#     optimizer=Adam(learning_rate=0.001),
#     loss='mse',
#     metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.5926 - mean_absolute_error: 1.1092 - val_loss: 0.5120 - val_mean_absolute_error: 0.4576
# Epoch 2/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.9027 - mean_absolute_error: 1.2029 - val_loss: 0.5236 - val_mean_absolute_error: 0.4577
# Epoch 3/100
# 67/67 [==============================] - 1s 17ms/step - loss: 2.6725 - mean_absolute_error: 1.1218 - val_loss: 0.7739 - val_mean_absolute_error: 0.7152
# Epoch 4/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.6623 - mean_absolute_error: 1.1083 - val_loss: 0.5849 - val_mean_absolute_error: 0.5616
# Epoch 5/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.7334 - mean_absolute_error: 1.1512 - val_loss: 0.6939 - val_mean_absolute_error: 0.6507
# Epoch 6/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.5921 - mean_absolute_error: 1.0992 - val_loss: 0.5438 - val_mean_absolute_error: 0.5166
# Epoch 7/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.5937 - mean_absolute_error: 1.1076 - val_loss: 0.6053 - val_mean_absolute_error: 0.5206
# Epoch 8/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.7724 - mean_absolute_error: 1.1808 - val_loss: 0.6581 - val_mean_absolute_error: 0.6254
# Epoch 9/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.6592 - mean_absolute_error: 1.1379 - val_loss: 0.7201 - val_mean_absolute_error: 0.6741
# Epoch 10/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.7889 - mean_absolute_error: 1.1574 - val_loss: 0.5279 - val_mean_absolute_error: 0.4625
# Epoch 11/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.7663 - mean_absolute_error: 1.1739 - val_loss: 0.5145 - val_mean_absolute_error: 0.4592
# Epoch 12/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.9048 - mean_absolute_error: 1.2096 - val_loss: 0.5689 - val_mean_absolute_error: 0.4916
# Epoch 13/100
# 67/67 [==============================] - 1s 10ms/step - loss: 3.0320 - mean_absolute_error: 1.2397 - val_loss: 0.7423 - val_mean_absolute_error: 0.6206
# Epoch 14/100
# 67/67 [==============================] - 1s 10ms/step - loss: 3.4065 - mean_absolute_error: 1.3489 - val_loss: 0.5907 - val_mean_absolute_error: 0.5594
# Epoch 15/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.9944 - mean_absolute_error: 1.2388 - val_loss: 0.5351 - val_mean_absolute_error: 0.4942
# Epoch 16/100
# 67/67 [==============================] - 1s 11ms/step - loss: 3.0161 - mean_absolute_error: 1.2291 - val_loss: 0.5829 - val_mean_absolute_error: 0.5443
# Epoch 17/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.7585 - mean_absolute_error: 1.1681 - val_loss: 0.8153 - val_mean_absolute_error: 0.7414
# Epoch 18/100
# 67/67 [==============================] - 1s 13ms/step - loss: 2.6082 - mean_absolute_error: 1.1032 - val_loss: 0.5351 - val_mean_absolute_error: 0.4720
# Epoch 19/100
# 67/67 [==============================] - 1s 21ms/step - loss: 2.6743 - mean_absolute_error: 1.1134 - val_loss: 0.6181 - val_mean_absolute_error: 0.5286
# Epoch 20/100
# 67/67 [==============================] - 1s 21ms/step - loss: 3.0255 - mean_absolute_error: 1.2298 - val_loss: 1.1752 - val_mean_absolute_error: 0.9408
# Epoch 21/100
# 67/67 [==============================] - 1s 17ms/step - loss: 3.0378 - mean_absolute_error: 1.2433 - val_loss: 0.9215 - val_mean_absolute_error: 0.7521
# Epoch 22/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.6694 - mean_absolute_error: 1.1372 - val_loss: 1.1952 - val_mean_absolute_error: 0.9591
# Epoch 23/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.5780 - mean_absolute_error: 1.1096 - val_loss: 0.8833 - val_mean_absolute_error: 0.7242
# Epoch 24/100
# 67/67 [==============================] - 1s 10ms/step - loss: 3.0507 - mean_absolute_error: 1.2664 - val_loss: 1.0227 - val_mean_absolute_error: 0.8655
# Epoch 25/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.5206 - mean_absolute_error: 1.0975 - val_loss: 0.5260 - val_mean_absolute_error: 0.4614
# Epoch 26/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.4040 - mean_absolute_error: 1.0379 - val_loss: 0.9932 - val_mean_absolute_error: 0.8513
# Epoch 27/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.6593 - mean_absolute_error: 1.1407 - val_loss: 0.5143 - val_mean_absolute_error: 0.4620
# Epoch 28/100
# 67/67 [==============================] - 1s 10ms/step - loss: 3.8097 - mean_absolute_error: 1.4388 - val_loss: 1.5054 - val_mean_absolute_error: 1.0961
# Epoch 29/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.7177 - mean_absolute_error: 1.1226 - val_loss: 0.6158 - val_mean_absolute_error: 0.5893
# Epoch 30/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.4107 - mean_absolute_error: 1.0555 - val_loss: 0.5665 - val_mean_absolute_error: 0.4875
# Epoch 31/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.7546 - mean_absolute_error: 1.1810 - val_loss: 1.1473 - val_mean_absolute_error: 0.9321
# Epoch 32/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.8515 - mean_absolute_error: 1.1714 - val_loss: 0.6660 - val_mean_absolute_error: 0.5759
# Epoch 33/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.2985 - mean_absolute_error: 0.9999 - val_loss: 0.5624 - val_mean_absolute_error: 0.5381
# Epoch 34/100
# 67/67 [==============================] - 1s 11ms/step - loss: 3.2377 - mean_absolute_error: 1.2882 - val_loss: 0.5949 - val_mean_absolute_error: 0.5584
# Epoch 35/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.4795 - mean_absolute_error: 1.0844 - val_loss: 0.5703 - val_mean_absolute_error: 0.4916
# Epoch 36/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.7339 - mean_absolute_error: 1.1498 - val_loss: 0.5419 - val_mean_absolute_error: 0.5099
# Epoch 37/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.5286 - mean_absolute_error: 1.0885 - val_loss: 0.5294 - val_mean_absolute_error: 0.4849
# Epoch 38/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.4810 - mean_absolute_error: 1.0586 - val_loss: 0.7888 - val_mean_absolute_error: 0.6489
# Epoch 39/100
# 67/67 [==============================] - 1s 10ms/step - loss: 3.0312 - mean_absolute_error: 1.2415 - val_loss: 0.5442 - val_mean_absolute_error: 0.5102
# Epoch 40/100
# 67/67 [==============================] - 1s 11ms/step - loss: 3.5343 - mean_absolute_error: 1.3613 - val_loss: 0.6559 - val_mean_absolute_error: 0.6110
# Epoch 41/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.5803 - mean_absolute_error: 1.1060 - val_loss: 0.8580 - val_mean_absolute_error: 0.7665
# Epoch 42/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.3020 - mean_absolute_error: 0.9988 - val_loss: 0.9025 - val_mean_absolute_error: 0.7955
# Epoch 43/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.4838 - mean_absolute_error: 1.0884 - val_loss: 0.5417 - val_mean_absolute_error: 0.4707
# Epoch 44/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.8108 - mean_absolute_error: 1.1774 - val_loss: 0.7516 - val_mean_absolute_error: 0.6992
# Epoch 45/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.7455 - mean_absolute_error: 1.1706 - val_loss: 0.6549 - val_mean_absolute_error: 0.6161
# Epoch 46/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.9033 - mean_absolute_error: 1.2068 - val_loss: 2.6388 - val_mean_absolute_error: 1.5099
# Epoch 47/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.5832 - mean_absolute_error: 1.1160 - val_loss: 0.6299 - val_mean_absolute_error: 0.5876
# Epoch 48/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.3634 - mean_absolute_error: 1.0544 - val_loss: 0.8615 - val_mean_absolute_error: 0.7064
# Epoch 49/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.7078 - mean_absolute_error: 1.1392 - val_loss: 2.3398 - val_mean_absolute_error: 1.4134
# Epoch 50/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.9127 - mean_absolute_error: 1.2014 - val_loss: 0.8428 - val_mean_absolute_error: 0.6936
# Epoch 51/100
# 67/67 [==============================] - 1s 12ms/step - loss: 2.3799 - mean_absolute_error: 1.0610 - val_loss: 0.5225 - val_mean_absolute_error: 0.4536
# Epoch 52/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.4211 - mean_absolute_error: 1.0581 - val_loss: 0.6199 - val_mean_absolute_error: 0.5960
# Epoch 53/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.3919 - mean_absolute_error: 1.0393 - val_loss: 0.6011 - val_mean_absolute_error: 0.5422
# Epoch 54/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.6986 - mean_absolute_error: 1.1523 - val_loss: 0.7692 - val_mean_absolute_error: 0.6457
# Epoch 55/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.5123 - mean_absolute_error: 1.0795 - val_loss: 0.8643 - val_mean_absolute_error: 0.7736
# Epoch 56/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.4231 - mean_absolute_error: 1.0745 - val_loss: 1.7641 - val_mean_absolute_error: 1.2017
# Epoch 57/100
# 67/67 [==============================] - 1s 10ms/step - loss: 3.9112 - mean_absolute_error: 1.4661 - val_loss: 0.5897 - val_mean_absolute_error: 0.5617
# Epoch 58/100
# 67/67 [==============================] - 1s 10ms/step - loss: 3.2520 - mean_absolute_error: 1.2963 - val_loss: 0.5388 - val_mean_absolute_error: 0.4952
# Epoch 59/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.6053 - mean_absolute_error: 1.1200 - val_loss: 1.9123 - val_mean_absolute_error: 1.2578
# Epoch 60/100
# 67/67 [==============================] - 1s 11ms/step - loss: 3.1348 - mean_absolute_error: 1.2540 - val_loss: 0.6170 - val_mean_absolute_error: 0.5861
# Epoch 61/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.7123 - mean_absolute_error: 1.1621 - val_loss: 0.6376 - val_mean_absolute_error: 0.6042
# Epoch 62/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.7532 - mean_absolute_error: 1.1674 - val_loss: 0.7662 - val_mean_absolute_error: 0.6427
# Epoch 63/100
# 67/67 [==============================] - 1s 11ms/step - loss: 3.1047 - mean_absolute_error: 1.2656 - val_loss: 0.5184 - val_mean_absolute_error: 0.4707
# Epoch 64/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.4439 - mean_absolute_error: 1.0630 - val_loss: 0.9900 - val_mean_absolute_error: 0.8443
# Epoch 65/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.4877 - mean_absolute_error: 1.0885 - val_loss: 1.6665 - val_mean_absolute_error: 1.1658
# Epoch 66/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.8432 - mean_absolute_error: 1.1907 - val_loss: 0.7489 - val_mean_absolute_error: 0.6968
# Epoch 67/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.7966 - mean_absolute_error: 1.1849 - val_loss: 0.5294 - val_mean_absolute_error: 0.5034
# Epoch 68/100
# 67/67 [==============================] - 1s 11ms/step - loss: 3.5532 - mean_absolute_error: 1.4219 - val_loss: 0.5630 - val_mean_absolute_error: 0.4835
# Epoch 69/100
# 67/67 [==============================] - 1s 12ms/step - loss: 2.5200 - mean_absolute_error: 1.0837 - val_loss: 0.6844 - val_mean_absolute_error: 0.6527
# Epoch 70/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.4886 - mean_absolute_error: 1.0899 - val_loss: 0.5818 - val_mean_absolute_error: 0.5072
# Epoch 71/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.3721 - mean_absolute_error: 1.0499 - val_loss: 0.7968 - val_mean_absolute_error: 0.7257
# Epoch 72/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.4744 - mean_absolute_error: 1.0607 - val_loss: 0.5485 - val_mean_absolute_error: 0.5124
# Epoch 73/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.6219 - mean_absolute_error: 1.1301 - val_loss: 0.8593 - val_mean_absolute_error: 0.7154
# Epoch 74/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.4674 - mean_absolute_error: 1.0646 - val_loss: 0.5216 - val_mean_absolute_error: 0.4637
# Epoch 75/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.4903 - mean_absolute_error: 1.0718 - val_loss: 0.7829 - val_mean_absolute_error: 0.6531
# Epoch 76/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.6206 - mean_absolute_error: 1.1301 - val_loss: 0.5201 - val_mean_absolute_error: 0.4687
# Epoch 77/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.3628 - mean_absolute_error: 1.0319 - val_loss: 0.5275 - val_mean_absolute_error: 0.4646
# Epoch 78/100
# 67/67 [==============================] - 1s 11ms/step - loss: 3.3237 - mean_absolute_error: 1.3235 - val_loss: 0.7062 - val_mean_absolute_error: 0.6624
# Epoch 79/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.4354 - mean_absolute_error: 1.0546 - val_loss: 0.7667 - val_mean_absolute_error: 0.7129
# Epoch 80/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.3246 - mean_absolute_error: 1.0230 - val_loss: 0.6012 - val_mean_absolute_error: 0.5807
# Epoch 81/100
# 67/67 [==============================] - 1s 11ms/step - loss: 3.0014 - mean_absolute_error: 1.2555 - val_loss: 0.7143 - val_mean_absolute_error: 0.6064
# Epoch 82/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.5862 - mean_absolute_error: 1.1244 - val_loss: 0.5096 - val_mean_absolute_error: 0.4660
# Epoch 83/100
# 67/67 [==============================] - 1s 11ms/step - loss: 4.0251 - mean_absolute_error: 1.4912 - val_loss: 0.5385 - val_mean_absolute_error: 0.5256
# Epoch 84/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.7880 - mean_absolute_error: 1.1650 - val_loss: 0.9037 - val_mean_absolute_error: 0.7878
# Epoch 85/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.7758 - mean_absolute_error: 1.1694 - val_loss: 0.6696 - val_mean_absolute_error: 0.6359
# Epoch 86/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.4856 - mean_absolute_error: 1.0653 - val_loss: 0.6814 - val_mean_absolute_error: 0.6322
# Epoch 87/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.4608 - mean_absolute_error: 1.0644 - val_loss: 0.6174 - val_mean_absolute_error: 0.5339
# Epoch 88/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.4135 - mean_absolute_error: 1.0431 - val_loss: 0.9866 - val_mean_absolute_error: 0.7899
# Epoch 89/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.7773 - mean_absolute_error: 1.1736 - val_loss: 0.5122 - val_mean_absolute_error: 0.4635
# Epoch 90/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.3904 - mean_absolute_error: 1.0583 - val_loss: 0.5543 - val_mean_absolute_error: 0.5056
# Epoch 91/100
# 67/67 [==============================] - 1s 10ms/step - loss: 2.2978 - mean_absolute_error: 1.0095 - val_loss: 0.9507 - val_mean_absolute_error: 0.8257
# Epoch 92/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.4350 - mean_absolute_error: 1.0508 - val_loss: 0.8127 - val_mean_absolute_error: 0.7411
# Epoch 93/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.3749 - mean_absolute_error: 1.0547 - val_loss: 0.6750 - val_mean_absolute_error: 0.6272
# Epoch 94/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.6968 - mean_absolute_error: 1.1462 - val_loss: 0.5482 - val_mean_absolute_error: 0.5270
# Epoch 95/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.5652 - mean_absolute_error: 1.1088 - val_loss: 1.0894 - val_mean_absolute_error: 0.9047
# Epoch 96/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.6665 - mean_absolute_error: 1.1462 - val_loss: 0.5499 - val_mean_absolute_error: 0.5232
# Epoch 97/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.5014 - mean_absolute_error: 1.1033 - val_loss: 0.7917 - val_mean_absolute_error: 0.7199
# Epoch 98/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.5904 - mean_absolute_error: 1.1057 - val_loss: 0.9430 - val_mean_absolute_error: 0.8164
# Epoch 99/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.5939 - mean_absolute_error: 1.1289 - val_loss: 0.5754 - val_mean_absolute_error: 0.5603
# Epoch 100/100
# 67/67 [==============================] - 1s 11ms/step - loss: 2.5222 - mean_absolute_error: 1.0948 - val_loss: 0.6302 - val_mean_absolute_error: 0.5959

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               66560
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 91,521
# Trainable params: 91,521
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])

# %%
results = model.evaluate(X_train, y_train)
# Out:
# 67/67 [==============================] - 0s 4ms/step - loss: 2.2069 - mean_absolute_error: 0.9473

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.xticks(rotation = 45)
plt.legend(['Validation Predictions', 'Validation Observations'])

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.xticks(rotation = 45)
plt.legend(['Testing Predictions', 'Testing Observations'])

# %%
results = model.evaluate(X_test, y_test)
# Out:
# 9/9 [==============================] - 0s 4ms/step - loss: 0.9620 - mean_absolute_error: 0.6960

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])
