# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ML/updated/ACI_HistoricalPrices - ACI_HistoricalPrices.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df
# Out:
#             Date    Open    High     Low   Close       Volume
# 0     1997-07-07   15.44   15.44   15.44   15.44  52691.85443
# 1     1997-07-09   15.66   15.66   15.66   15.66  20513.62272
# 2     1997-07-10   15.53   15.53   15.53   15.53  11262.38110
# 3     1997-07-14   14.52   14.52   14.52   14.52  30167.09223
# 4     1997-07-16   14.67   14.67   14.67   14.67  45853.98019
# ...          ...     ...     ...     ...     ...          ...
# 4530  2022-08-03  277.50  279.10  276.70  277.10  51452.00000
# 4531  2022-08-04  278.70  278.70  275.40  276.70  45600.00000
# 4532  2022-08-08  279.90  279.90  275.70  277.80  28651.00000
# 4533  2022-08-10  277.00  277.00  273.60  273.90  39391.00000
# 4534  2022-08-11  274.30  275.80  273.80  274.40  25184.00000
#
# [4535 rows x 6 columns]

# %%
df = df[['Date', 'Close']]
df.head(10)
# Out:
#          Date  Close
# 0  1997-07-07  15.44
# 1  1997-07-09  15.66
# 2  1997-07-10  15.53
# 3  1997-07-14  14.52
# 4  1997-07-16  14.67
# 5  1997-07-17  14.90
# 6  1997-07-21  13.78
# 7  1997-07-22  13.91
# 8  1997-07-23  14.11
# 9  1997-07-28  16.07

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1998-08-23')
datetime_object
# Out:
# datetime.datetime(1998, 8, 23, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Date']
# Out:
# 0      1997-07-07
# 1      1997-07-09
# 2      1997-07-10
# 3      1997-07-14
# 4      1997-07-16
#           ...
# 4530   2022-08-03
# 4531   2022-08-04
# 4532   2022-08-08
# 4533   2022-08-10
# 4534   2022-08-11
# Name: Date, Length: 4535, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')

# %%
df.index
# Out:
# DatetimeIndex(['1997-07-07', '1997-07-09', '1997-07-10', '1997-07-14',
#                '1997-07-16', '1997-07-17', '1997-07-21', '1997-07-22',
#                '1997-07-23', '1997-07-28',
#                ...
#                '2022-07-26', '2022-07-27', '2022-07-28', '2022-08-01',
#                '2022-08-02', '2022-08-03', '2022-08-04', '2022-08-08',
#                '2022-08-10', '2022-08-11'],
#               dtype='datetime64[ns]', name='Date', length=4535, freq=None)

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  #print(target_date)
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+2)
    #print(df_subset)
    
    if len(df_subset) != n+2:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=100)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n+1):
    X[:, i]
    ret_df[f'Target-{n+1-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# %%
# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '1998-08-23', 
                                '2022-08-11',                         
                                n=5)
windowed_df
# Out:
#      Target Date  Target-6  Target-5  Target-4  Target-3  Target-2  Target-1  \
# 0     1998-08-23      9.21      9.26      9.46      9.40      9.41      9.40
# 1     1998-08-25      9.46      9.40      9.41      9.40      8.29      7.90
# 2     1998-08-26      9.40      9.41      9.40      8.29      7.90      7.69
# 3     1998-08-27      9.41      9.40      8.29      7.90      7.69      7.55
# 4     1998-08-31      9.40      8.29      7.90      7.69      7.55      7.50
# ...          ...       ...       ...       ...       ...       ...       ...
# 4450  2022-08-03    276.40    274.00    271.70    271.50    273.70    276.70
# 4451  2022-08-04    274.00    271.70    271.50    273.70    276.70    277.10
# 4452  2022-08-08    271.70    271.50    273.70    276.70    277.10    276.70
# 4453  2022-08-10    271.50    273.70    276.70    277.10    276.70    277.80
# 4454  2022-08-11    273.70    276.70    277.10    276.70    277.80    273.90
#
#       Target
# 0       8.29
# 1       7.69
# 2       7.55
# 3       7.50
# 4       7.48
# ...      ...
# 4450  277.10
# 4451  276.70
# 4452  277.80
# 4453  273.90
# 4454  274.40
#
# [4455 rows x 8 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((4455,), (4455, 6, 1), (4455,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90,]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((6, 1)),
                    layers.LSTM(128),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', optimizer=Adam(learning_rate=0.001), metrics=['mean_absolute_error'])

# model.compile(
#     optimizer=Adam(learning_rate=0.001),
#     loss='mse',
#     metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 112/112 [==============================] - 5s 16ms/step - loss: 5245.3623 - mean_absolute_error: 34.8816 - val_loss: 83.4697 - val_mean_absolute_error: 7.0003
# Epoch 2/100
# 112/112 [==============================] - 1s 11ms/step - loss: 18.6397 - mean_absolute_error: 2.3006 - val_loss: 287.7319 - val_mean_absolute_error: 16.0657
# Epoch 3/100
# 112/112 [==============================] - 1s 10ms/step - loss: 24.6580 - mean_absolute_error: 2.6332 - val_loss: 124.1298 - val_mean_absolute_error: 10.2063
# Epoch 4/100
# 112/112 [==============================] - 1s 10ms/step - loss: 19.9754 - mean_absolute_error: 2.2840 - val_loss: 40.5021 - val_mean_absolute_error: 5.0512
# Epoch 5/100
# 112/112 [==============================] - 1s 11ms/step - loss: 14.2482 - mean_absolute_error: 2.0260 - val_loss: 24.4349 - val_mean_absolute_error: 3.1677
# Epoch 6/100
# 112/112 [==============================] - 2s 15ms/step - loss: 14.0168 - mean_absolute_error: 2.0455 - val_loss: 89.2815 - val_mean_absolute_error: 8.4945
# Epoch 7/100
# 112/112 [==============================] - 2s 17ms/step - loss: 14.3824 - mean_absolute_error: 2.0677 - val_loss: 36.8680 - val_mean_absolute_error: 4.6542
# Epoch 8/100
# 112/112 [==============================] - 2s 14ms/step - loss: 16.4187 - mean_absolute_error: 2.2598 - val_loss: 45.5945 - val_mean_absolute_error: 5.4781
# Epoch 9/100
# 112/112 [==============================] - 1s 10ms/step - loss: 16.1324 - mean_absolute_error: 2.3070 - val_loss: 25.2222 - val_mean_absolute_error: 3.3531
# Epoch 10/100
# 112/112 [==============================] - 1s 11ms/step - loss: 11.7671 - mean_absolute_error: 1.9313 - val_loss: 116.1589 - val_mean_absolute_error: 9.8248
# Epoch 11/100
# 112/112 [==============================] - 1s 10ms/step - loss: 28.3324 - mean_absolute_error: 2.8549 - val_loss: 31.3732 - val_mean_absolute_error: 4.1026
# Epoch 12/100
# 112/112 [==============================] - 1s 10ms/step - loss: 10.8896 - mean_absolute_error: 1.7395 - val_loss: 227.2164 - val_mean_absolute_error: 14.0374
# Epoch 13/100
# 112/112 [==============================] - 1s 10ms/step - loss: 20.2841 - mean_absolute_error: 2.5852 - val_loss: 23.4733 - val_mean_absolute_error: 3.1221
# Epoch 14/100
# 112/112 [==============================] - 1s 10ms/step - loss: 11.8901 - mean_absolute_error: 1.9353 - val_loss: 66.8548 - val_mean_absolute_error: 6.8876
# Epoch 15/100
# 112/112 [==============================] - 1s 10ms/step - loss: 19.5318 - mean_absolute_error: 2.3620 - val_loss: 28.9222 - val_mean_absolute_error: 3.7468
# Epoch 16/100
# 112/112 [==============================] - 1s 11ms/step - loss: 14.5364 - mean_absolute_error: 1.9966 - val_loss: 25.0557 - val_mean_absolute_error: 3.4191
# Epoch 17/100
# 112/112 [==============================] - 1s 11ms/step - loss: 28.7248 - mean_absolute_error: 2.8113 - val_loss: 27.2932 - val_mean_absolute_error: 3.5463
# Epoch 18/100
# 112/112 [==============================] - 1s 11ms/step - loss: 12.0780 - mean_absolute_error: 1.8579 - val_loss: 23.6408 - val_mean_absolute_error: 3.1801
# Epoch 19/100
# 112/112 [==============================] - 1s 11ms/step - loss: 11.9806 - mean_absolute_error: 1.8687 - val_loss: 25.4485 - val_mean_absolute_error: 3.4063
# Epoch 20/100
# 112/112 [==============================] - 1s 10ms/step - loss: 14.2607 - mean_absolute_error: 2.0785 - val_loss: 27.0589 - val_mean_absolute_error: 3.5993
# Epoch 21/100
# 112/112 [==============================] - 1s 11ms/step - loss: 11.2020 - mean_absolute_error: 1.8589 - val_loss: 23.0054 - val_mean_absolute_error: 3.0467
# Epoch 22/100
# 112/112 [==============================] - 1s 10ms/step - loss: 18.6878 - mean_absolute_error: 2.2102 - val_loss: 187.2632 - val_mean_absolute_error: 12.8707
# Epoch 23/100
# 112/112 [==============================] - 1s 10ms/step - loss: 16.7990 - mean_absolute_error: 2.1333 - val_loss: 23.6312 - val_mean_absolute_error: 3.1106
# Epoch 24/100
# 112/112 [==============================] - 1s 10ms/step - loss: 11.8088 - mean_absolute_error: 1.9242 - val_loss: 125.6657 - val_mean_absolute_error: 10.2688
# Epoch 25/100
# 112/112 [==============================] - 1s 10ms/step - loss: 12.4191 - mean_absolute_error: 1.9430 - val_loss: 35.7508 - val_mean_absolute_error: 4.5726
# Epoch 26/100
# 112/112 [==============================] - 1s 10ms/step - loss: 16.0270 - mean_absolute_error: 2.1881 - val_loss: 27.0809 - val_mean_absolute_error: 3.6071
# Epoch 27/100
# 112/112 [==============================] - 1s 10ms/step - loss: 17.3606 - mean_absolute_error: 2.2885 - val_loss: 31.3899 - val_mean_absolute_error: 4.0346
# Epoch 28/100
# 112/112 [==============================] - 1s 10ms/step - loss: 29.1595 - mean_absolute_error: 2.8183 - val_loss: 33.0219 - val_mean_absolute_error: 4.2587
# Epoch 29/100
# 112/112 [==============================] - 1s 10ms/step - loss: 32.2618 - mean_absolute_error: 2.9621 - val_loss: 39.6752 - val_mean_absolute_error: 4.9897
# Epoch 30/100
# 112/112 [==============================] - 1s 10ms/step - loss: 11.6238 - mean_absolute_error: 1.8632 - val_loss: 38.9890 - val_mean_absolute_error: 4.9327
# Epoch 31/100
# 112/112 [==============================] - 1s 10ms/step - loss: 9.4115 - mean_absolute_error: 1.6088 - val_loss: 32.7240 - val_mean_absolute_error: 4.2819
# Epoch 32/100
# 112/112 [==============================] - 1s 10ms/step - loss: 18.2727 - mean_absolute_error: 2.3305 - val_loss: 34.2792 - val_mean_absolute_error: 4.4227
# Epoch 33/100
# 112/112 [==============================] - 1s 10ms/step - loss: 12.4488 - mean_absolute_error: 1.9505 - val_loss: 23.7273 - val_mean_absolute_error: 3.2005
# Epoch 34/100
# 112/112 [==============================] - 1s 10ms/step - loss: 14.0072 - mean_absolute_error: 2.0361 - val_loss: 24.6791 - val_mean_absolute_error: 3.3430
# Epoch 35/100
# 112/112 [==============================] - 1s 11ms/step - loss: 11.7989 - mean_absolute_error: 1.8099 - val_loss: 26.0329 - val_mean_absolute_error: 3.4547
# Epoch 36/100
# 112/112 [==============================] - 1s 10ms/step - loss: 16.3310 - mean_absolute_error: 2.2333 - val_loss: 209.7929 - val_mean_absolute_error: 13.6285
# Epoch 37/100
# 112/112 [==============================] - 1s 10ms/step - loss: 12.2922 - mean_absolute_error: 1.9239 - val_loss: 29.5610 - val_mean_absolute_error: 3.8745
# Epoch 38/100
# 112/112 [==============================] - 1s 11ms/step - loss: 14.1702 - mean_absolute_error: 2.0419 - val_loss: 93.2026 - val_mean_absolute_error: 8.6109
# Epoch 39/100
# 112/112 [==============================] - 1s 10ms/step - loss: 9.7253 - mean_absolute_error: 1.6856 - val_loss: 62.2133 - val_mean_absolute_error: 6.6130
# Epoch 40/100
# 112/112 [==============================] - 1s 10ms/step - loss: 20.3408 - mean_absolute_error: 2.5273 - val_loss: 32.3234 - val_mean_absolute_error: 4.2543
# Epoch 41/100
# 112/112 [==============================] - 1s 11ms/step - loss: 12.6229 - mean_absolute_error: 1.9535 - val_loss: 48.9373 - val_mean_absolute_error: 5.6444
# Epoch 42/100
# 112/112 [==============================] - 1s 10ms/step - loss: 29.7269 - mean_absolute_error: 2.9099 - val_loss: 33.5256 - val_mean_absolute_error: 4.2862
# Epoch 43/100
# 112/112 [==============================] - 1s 10ms/step - loss: 12.9898 - mean_absolute_error: 1.9402 - val_loss: 24.1427 - val_mean_absolute_error: 3.1999
# Epoch 44/100
# 112/112 [==============================] - 1s 10ms/step - loss: 9.8552 - mean_absolute_error: 1.6481 - val_loss: 30.8480 - val_mean_absolute_error: 3.9729
# Epoch 45/100
# 112/112 [==============================] - 1s 11ms/step - loss: 11.0646 - mean_absolute_error: 1.8016 - val_loss: 25.2201 - val_mean_absolute_error: 3.4161
# Epoch 46/100
# 112/112 [==============================] - 1s 11ms/step - loss: 13.4675 - mean_absolute_error: 1.9980 - val_loss: 24.3961 - val_mean_absolute_error: 3.3217
# Epoch 47/100
# 112/112 [==============================] - 1s 11ms/step - loss: 14.7257 - mean_absolute_error: 2.0808 - val_loss: 23.1561 - val_mean_absolute_error: 3.0229
# Epoch 48/100
# 112/112 [==============================] - 1s 11ms/step - loss: 12.4314 - mean_absolute_error: 1.8820 - val_loss: 31.6402 - val_mean_absolute_error: 3.9787
# Epoch 49/100
# 112/112 [==============================] - 1s 11ms/step - loss: 14.3171 - mean_absolute_error: 2.0177 - val_loss: 63.1879 - val_mean_absolute_error: 6.7371
# Epoch 50/100
# 112/112 [==============================] - 1s 11ms/step - loss: 10.5458 - mean_absolute_error: 1.7460 - val_loss: 49.9110 - val_mean_absolute_error: 5.8203
# Epoch 51/100
# 112/112 [==============================] - 2s 18ms/step - loss: 12.0015 - mean_absolute_error: 1.8175 - val_loss: 49.5168 - val_mean_absolute_error: 5.6923
# Epoch 52/100
# 112/112 [==============================] - 2s 15ms/step - loss: 10.9061 - mean_absolute_error: 1.7892 - val_loss: 23.2671 - val_mean_absolute_error: 3.0485
# Epoch 53/100
# 112/112 [==============================] - 1s 10ms/step - loss: 10.5012 - mean_absolute_error: 1.7770 - val_loss: 59.3047 - val_mean_absolute_error: 6.5569
# Epoch 54/100
# 112/112 [==============================] - 1s 11ms/step - loss: 11.5953 - mean_absolute_error: 1.9163 - val_loss: 31.9044 - val_mean_absolute_error: 4.1550
# Epoch 55/100
# 112/112 [==============================] - 1s 11ms/step - loss: 16.7450 - mean_absolute_error: 2.2198 - val_loss: 48.7755 - val_mean_absolute_error: 5.7813
# Epoch 56/100
# 112/112 [==============================] - 1s 11ms/step - loss: 11.4098 - mean_absolute_error: 1.7859 - val_loss: 58.3552 - val_mean_absolute_error: 6.4800
# Epoch 57/100
# 112/112 [==============================] - 1s 11ms/step - loss: 13.5252 - mean_absolute_error: 2.0376 - val_loss: 34.4126 - val_mean_absolute_error: 4.4417
# Epoch 58/100
# 112/112 [==============================] - 1s 10ms/step - loss: 12.2885 - mean_absolute_error: 1.8881 - val_loss: 27.3953 - val_mean_absolute_error: 3.4379
# Epoch 59/100
# 112/112 [==============================] - 1s 10ms/step - loss: 14.0329 - mean_absolute_error: 2.0655 - val_loss: 24.4590 - val_mean_absolute_error: 3.3075
# Epoch 60/100
# 112/112 [==============================] - 1s 11ms/step - loss: 12.1912 - mean_absolute_error: 1.9230 - val_loss: 44.9407 - val_mean_absolute_error: 5.3889
# Epoch 61/100
# 112/112 [==============================] - 1s 11ms/step - loss: 16.0626 - mean_absolute_error: 2.2484 - val_loss: 55.8693 - val_mean_absolute_error: 6.2579
# Epoch 62/100
# 112/112 [==============================] - 1s 10ms/step - loss: 12.3306 - mean_absolute_error: 1.9725 - val_loss: 38.8724 - val_mean_absolute_error: 4.9017
# Epoch 63/100
# 112/112 [==============================] - 1s 10ms/step - loss: 11.2420 - mean_absolute_error: 1.8429 - val_loss: 23.8961 - val_mean_absolute_error: 3.1828
# Epoch 64/100
# 112/112 [==============================] - 1s 10ms/step - loss: 10.8371 - mean_absolute_error: 1.7151 - val_loss: 37.9083 - val_mean_absolute_error: 4.5607
# Epoch 65/100
# 112/112 [==============================] - 1s 10ms/step - loss: 14.1061 - mean_absolute_error: 2.0296 - val_loss: 24.9694 - val_mean_absolute_error: 3.3587
# Epoch 66/100
# 112/112 [==============================] - 1s 10ms/step - loss: 11.2106 - mean_absolute_error: 1.7815 - val_loss: 25.1764 - val_mean_absolute_error: 3.3294
# Epoch 67/100
# 112/112 [==============================] - 1s 11ms/step - loss: 11.2376 - mean_absolute_error: 1.7462 - val_loss: 50.7304 - val_mean_absolute_error: 5.8777
# Epoch 68/100
# 112/112 [==============================] - 1s 10ms/step - loss: 11.1275 - mean_absolute_error: 1.7977 - val_loss: 27.1795 - val_mean_absolute_error: 3.6237
# Epoch 69/100
# 112/112 [==============================] - 1s 10ms/step - loss: 11.9374 - mean_absolute_error: 1.8909 - val_loss: 158.3329 - val_mean_absolute_error: 11.7673
# Epoch 70/100
# 112/112 [==============================] - 1s 10ms/step - loss: 20.6854 - mean_absolute_error: 2.5142 - val_loss: 238.7606 - val_mean_absolute_error: 14.5440
# Epoch 71/100
# 112/112 [==============================] - 1s 10ms/step - loss: 15.4009 - mean_absolute_error: 2.1568 - val_loss: 35.3635 - val_mean_absolute_error: 4.5306
# Epoch 72/100
# 112/112 [==============================] - 1s 10ms/step - loss: 10.8734 - mean_absolute_error: 1.7193 - val_loss: 113.5970 - val_mean_absolute_error: 9.6253
# Epoch 73/100
# 112/112 [==============================] - 1s 10ms/step - loss: 16.9882 - mean_absolute_error: 2.1829 - val_loss: 24.9320 - val_mean_absolute_error: 3.2167
# Epoch 74/100
# 112/112 [==============================] - 1s 10ms/step - loss: 9.3704 - mean_absolute_error: 1.6413 - val_loss: 30.0582 - val_mean_absolute_error: 3.8442
# Epoch 75/100
# 112/112 [==============================] - 1s 10ms/step - loss: 24.6905 - mean_absolute_error: 2.6186 - val_loss: 32.2537 - val_mean_absolute_error: 3.9133
# Epoch 76/100
# 112/112 [==============================] - 1s 10ms/step - loss: 12.6715 - mean_absolute_error: 1.9652 - val_loss: 118.9261 - val_mean_absolute_error: 9.8683
# Epoch 77/100
# 112/112 [==============================] - 1s 11ms/step - loss: 12.7864 - mean_absolute_error: 1.9308 - val_loss: 24.8303 - val_mean_absolute_error: 3.2883
# Epoch 78/100
# 112/112 [==============================] - 1s 11ms/step - loss: 11.7201 - mean_absolute_error: 1.8087 - val_loss: 79.1228 - val_mean_absolute_error: 7.6656
# Epoch 79/100
# 112/112 [==============================] - 1s 10ms/step - loss: 12.8153 - mean_absolute_error: 1.8895 - val_loss: 34.6846 - val_mean_absolute_error: 4.4681
# Epoch 80/100
# 112/112 [==============================] - 1s 12ms/step - loss: 11.7114 - mean_absolute_error: 1.8444 - val_loss: 30.2017 - val_mean_absolute_error: 3.9506
# Epoch 81/100
# 112/112 [==============================] - 2s 17ms/step - loss: 11.9262 - mean_absolute_error: 1.8506 - val_loss: 30.5888 - val_mean_absolute_error: 4.0242
# Epoch 82/100
# 112/112 [==============================] - 2s 18ms/step - loss: 14.5598 - mean_absolute_error: 2.1166 - val_loss: 23.3763 - val_mean_absolute_error: 3.0969
# Epoch 83/100
# 112/112 [==============================] - 1s 11ms/step - loss: 11.4359 - mean_absolute_error: 1.8365 - val_loss: 96.4938 - val_mean_absolute_error: 8.7955
# Epoch 84/100
# 112/112 [==============================] - 1s 11ms/step - loss: 13.1693 - mean_absolute_error: 1.9017 - val_loss: 24.6496 - val_mean_absolute_error: 3.2578
# Epoch 85/100
# 112/112 [==============================] - 1s 11ms/step - loss: 10.6463 - mean_absolute_error: 1.7670 - val_loss: 30.5967 - val_mean_absolute_error: 4.0252
# Epoch 86/100
# 112/112 [==============================] - 1s 11ms/step - loss: 14.1178 - mean_absolute_error: 2.0691 - val_loss: 27.5490 - val_mean_absolute_error: 3.6954
# Epoch 87/100
# 112/112 [==============================] - 1s 11ms/step - loss: 10.5140 - mean_absolute_error: 1.7760 - val_loss: 30.0732 - val_mean_absolute_error: 3.9249
# Epoch 88/100
# 112/112 [==============================] - 1s 11ms/step - loss: 9.9447 - mean_absolute_error: 1.6742 - val_loss: 23.4606 - val_mean_absolute_error: 3.0302
# Epoch 89/100
# 112/112 [==============================] - 1s 11ms/step - loss: 9.6553 - mean_absolute_error: 1.6616 - val_loss: 43.1831 - val_mean_absolute_error: 5.2495
# Epoch 90/100
# 112/112 [==============================] - 1s 11ms/step - loss: 11.6719 - mean_absolute_error: 1.8269 - val_loss: 24.3310 - val_mean_absolute_error: 3.1700
# Epoch 91/100
# 112/112 [==============================] - 1s 11ms/step - loss: 10.4040 - mean_absolute_error: 1.7141 - val_loss: 24.6970 - val_mean_absolute_error: 3.3379
# Epoch 92/100
# 112/112 [==============================] - 1s 11ms/step - loss: 11.4560 - mean_absolute_error: 1.8391 - val_loss: 37.4771 - val_mean_absolute_error: 4.7132
# Epoch 93/100
# 112/112 [==============================] - 1s 11ms/step - loss: 26.1895 - mean_absolute_error: 2.6949 - val_loss: 89.5630 - val_mean_absolute_error: 8.2394
# Epoch 94/100
# 112/112 [==============================] - 1s 11ms/step - loss: 9.8353 - mean_absolute_error: 1.6649 - val_loss: 101.7904 - val_mean_absolute_error: 9.1270
# Epoch 95/100
# 112/112 [==============================] - 1s 10ms/step - loss: 10.9332 - mean_absolute_error: 1.8081 - val_loss: 141.5253 - val_mean_absolute_error: 10.6541
# Epoch 96/100
# 112/112 [==============================] - 1s 10ms/step - loss: 10.9426 - mean_absolute_error: 1.7942 - val_loss: 37.2857 - val_mean_absolute_error: 4.7482
# Epoch 97/100
# 112/112 [==============================] - 1s 11ms/step - loss: 12.9426 - mean_absolute_error: 2.0026 - val_loss: 30.5616 - val_mean_absolute_error: 4.0782
# Epoch 98/100
# 112/112 [==============================] - 1s 11ms/step - loss: 10.2786 - mean_absolute_error: 1.7651 - val_loss: 27.2962 - val_mean_absolute_error: 3.5782
# Epoch 99/100
# 112/112 [==============================] - 1s 11ms/step - loss: 13.5159 - mean_absolute_error: 1.9209 - val_loss: 27.6808 - val_mean_absolute_error: 3.6962
# Epoch 100/100
# 112/112 [==============================] - 1s 10ms/step - loss: 11.6967 - mean_absolute_error: 1.8412 - val_loss: 34.5789 - val_mean_absolute_error: 4.3983

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 128)               66560
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  dense_11 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 91,521
# Trainable params: 91,521
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])

# %%
results = model.evaluate(X_train, y_train)
# Out:
# 112/112 [==============================] - 0s 4ms/step - loss: 11.2592 - mean_absolute_error: 1.7911

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.xticks(rotation = 45)
plt.legend(['Validation Predictions', 'Validation Observations'])

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.xticks(rotation = 45)
plt.legend(['Testing Predictions', 'Testing Observations'])

# %%
results = model.evaluate(X_test, y_test)
# Out:
# 14/14 [==============================] - 0s 5ms/step - loss: 35.3759 - mean_absolute_error: 4.6359

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])
