# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ML/updated/IslamiBank_HistoricalPrices - IslamiBank_HistoricalPrices.csv')

# %%
df
# Out:
#             Date   Open   High    Low  Close        Volume
# 0     1997-04-23   2.76   2.76   2.76   2.76  7.908723e+06
# 1     1997-07-07   2.37   2.37   2.37   2.37  1.835953e+05
# 2     1997-07-08   2.37   2.37   2.37   2.37  2.344371e+05
# 3     1997-07-09   2.34   2.34   2.34   2.34  2.824544e+04
# 4     1997-07-10   2.33   2.33   2.33   2.33  4.519270e+04
# ...          ...    ...    ...    ...    ...           ...
# 4365  2022-08-04  32.60  32.70  32.60  32.60  1.111740e+05
# 4366  2022-08-08  32.60  32.70  32.60  32.60  2.684520e+05
# 4367  2022-08-10  32.60  32.60  32.60  32.60  1.878880e+05
# 4368  2022-08-11  32.60  32.60  32.60  32.60  6.421100e+04
# 4369  2022-08-16  32.70  32.70  32.60  32.60  3.573840e+05
#
# [4370 rows x 6 columns]

# %%
df = df[['Date', 'Close']]
df.head(10)
# Out:
#          Date  Close
# 0  1997-04-23   2.76
# 1  1997-07-07   2.37
# 2  1997-07-08   2.37
# 3  1997-07-09   2.34
# 4  1997-07-10   2.33
# 5  1997-07-14   2.24
# 6  1997-07-16   2.20
# 7  1997-07-17   2.19
# 8  1997-07-21   2.17
# 9  1997-07-22   2.17

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1998-08-23')
datetime_object
# Out:
# datetime.datetime(1998, 8, 23, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Date']
# Out:
# 0      1997-04-23
# 1      1997-07-07
# 2      1997-07-08
# 3      1997-07-09
# 4      1997-07-10
#           ...
# 4365   2022-08-04
# 4366   2022-08-08
# 4367   2022-08-10
# 4368   2022-08-11
# 4369   2022-08-16
# Name: Date, Length: 4370, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')

# %%
df.index
# Out:
# DatetimeIndex(['1997-04-23', '1997-07-07', '1997-07-08', '1997-07-09',
#                '1997-07-10', '1997-07-14', '1997-07-16', '1997-07-17',
#                '1997-07-21', '1997-07-22',
#                ...
#                '2022-07-27', '2022-07-28', '2022-08-01', '2022-08-02',
#                '2022-08-03', '2022-08-04', '2022-08-08', '2022-08-10',
#                '2022-08-11', '2022-08-16'],
#               dtype='datetime64[ns]', name='Date', length=4370, freq=None)

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  #print(target_date)
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+2)
    #print(df_subset)
    
    if len(df_subset) != n+2:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=100)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n+1):
    X[:, i]
    ret_df[f'Target-{n+1-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# %%
# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '2010-08-23', 
                                '2022-08-11',                         
                                n=5)
windowed_df
# Out:
#      Target Date  Target-6  Target-5  Target-4  Target-3  Target-2  Target-1  \
# 0     2010-08-23     25.90     25.84     25.57     25.53     25.99     26.07
# 1     2010-08-24     25.84     25.57     25.53     25.99     26.07     25.61
# 2     2010-08-25     25.57     25.53     25.99     26.07     25.61     25.65
# 3     2010-08-26     25.53     25.99     26.07     25.61     25.65     25.50
# 4     2010-08-30     25.99     26.07     25.61     25.65     25.50     25.44
# ...          ...       ...       ...       ...       ...       ...       ...
# 2267  2022-08-03     32.70     32.70     32.60     32.30     32.60     32.60
# 2268  2022-08-04     32.70     32.60     32.30     32.60     32.60     32.60
# 2269  2022-08-08     32.60     32.30     32.60     32.60     32.60     32.60
# 2270  2022-08-10     32.30     32.60     32.60     32.60     32.60     32.60
# 2271  2022-08-11     32.60     32.60     32.60     32.60     32.60     32.60
#
#       Target
# 0      25.61
# 1      25.65
# 2      25.50
# 3      25.44
# 4      25.36
# ...      ...
# 2267   32.60
# 2268   32.60
# 2269   32.60
# 2270   32.60
# 2271   32.60
#
# [2272 rows x 8 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((2272,), (2272, 6, 1), (2272,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90,]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((6, 1)),
                    layers.LSTM(128),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', optimizer=Adam(learning_rate=0.001), metrics=['mean_absolute_error'])

# model.compile(
#     optimizer=Adam(learning_rate=0.001),
#     loss='mse',
#     metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 57/57 [==============================] - 4s 23ms/step - loss: 274.6597 - mean_absolute_error: 12.7619 - val_loss: 55.6394 - val_mean_absolute_error: 6.1084
# Epoch 2/100
# 57/57 [==============================] - 1s 12ms/step - loss: 12.7929 - mean_absolute_error: 2.5588 - val_loss: 0.7339 - val_mean_absolute_error: 0.6329
# Epoch 3/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.8152 - mean_absolute_error: 0.5855 - val_loss: 0.5445 - val_mean_absolute_error: 0.5144
# Epoch 4/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.6911 - mean_absolute_error: 0.5332 - val_loss: 0.5104 - val_mean_absolute_error: 0.4525
# Epoch 5/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.6419 - mean_absolute_error: 0.5168 - val_loss: 0.5245 - val_mean_absolute_error: 0.5233
# Epoch 6/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.7226 - mean_absolute_error: 0.5791 - val_loss: 0.5654 - val_mean_absolute_error: 0.5786
# Epoch 7/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.7067 - mean_absolute_error: 0.5838 - val_loss: 0.3890 - val_mean_absolute_error: 0.4123
# Epoch 8/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5726 - mean_absolute_error: 0.4792 - val_loss: 0.5834 - val_mean_absolute_error: 0.5662
# Epoch 9/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.6282 - mean_absolute_error: 0.5366 - val_loss: 0.3686 - val_mean_absolute_error: 0.3854
# Epoch 10/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5066 - mean_absolute_error: 0.4462 - val_loss: 0.3920 - val_mean_absolute_error: 0.3959
# Epoch 11/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5479 - mean_absolute_error: 0.4777 - val_loss: 0.3630 - val_mean_absolute_error: 0.3975
# Epoch 12/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5174 - mean_absolute_error: 0.4598 - val_loss: 0.3781 - val_mean_absolute_error: 0.3990
# Epoch 13/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.4824 - mean_absolute_error: 0.4440 - val_loss: 0.3482 - val_mean_absolute_error: 0.3714
# Epoch 14/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5598 - mean_absolute_error: 0.5049 - val_loss: 0.3918 - val_mean_absolute_error: 0.3985
# Epoch 15/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5460 - mean_absolute_error: 0.4798 - val_loss: 0.5350 - val_mean_absolute_error: 0.5456
# Epoch 16/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5356 - mean_absolute_error: 0.4763 - val_loss: 0.3630 - val_mean_absolute_error: 0.4134
# Epoch 17/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.4816 - mean_absolute_error: 0.4343 - val_loss: 0.3484 - val_mean_absolute_error: 0.3842
# Epoch 18/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5546 - mean_absolute_error: 0.4923 - val_loss: 0.5303 - val_mean_absolute_error: 0.5475
# Epoch 19/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5059 - mean_absolute_error: 0.4509 - val_loss: 0.3478 - val_mean_absolute_error: 0.3668
# Epoch 20/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.4797 - mean_absolute_error: 0.4318 - val_loss: 0.3474 - val_mean_absolute_error: 0.3739
# Epoch 21/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5426 - mean_absolute_error: 0.4953 - val_loss: 0.3390 - val_mean_absolute_error: 0.3800
# Epoch 22/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.4755 - mean_absolute_error: 0.4318 - val_loss: 0.3900 - val_mean_absolute_error: 0.4579
# Epoch 23/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5969 - mean_absolute_error: 0.5267 - val_loss: 0.3701 - val_mean_absolute_error: 0.4330
# Epoch 24/100
# 57/57 [==============================] - 1s 11ms/step - loss: 0.5075 - mean_absolute_error: 0.4566 - val_loss: 0.3840 - val_mean_absolute_error: 0.4100
# Epoch 25/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5266 - mean_absolute_error: 0.4635 - val_loss: 0.4457 - val_mean_absolute_error: 0.5187
# Epoch 26/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5127 - mean_absolute_error: 0.4649 - val_loss: 0.4991 - val_mean_absolute_error: 0.5243
# Epoch 27/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5121 - mean_absolute_error: 0.4678 - val_loss: 0.3396 - val_mean_absolute_error: 0.3722
# Epoch 28/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.4799 - mean_absolute_error: 0.4429 - val_loss: 0.5912 - val_mean_absolute_error: 0.6402
# Epoch 29/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5465 - mean_absolute_error: 0.5000 - val_loss: 0.3430 - val_mean_absolute_error: 0.3583
# Epoch 30/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5144 - mean_absolute_error: 0.4757 - val_loss: 0.3317 - val_mean_absolute_error: 0.3562
# Epoch 31/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.4900 - mean_absolute_error: 0.4445 - val_loss: 0.3763 - val_mean_absolute_error: 0.4053
# Epoch 32/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.6465 - mean_absolute_error: 0.5830 - val_loss: 0.3530 - val_mean_absolute_error: 0.4184
# Epoch 33/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5939 - mean_absolute_error: 0.5272 - val_loss: 0.3264 - val_mean_absolute_error: 0.3595
# Epoch 34/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5706 - mean_absolute_error: 0.5183 - val_loss: 0.6838 - val_mean_absolute_error: 0.6694
# Epoch 35/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.6857 - mean_absolute_error: 0.5882 - val_loss: 1.0562 - val_mean_absolute_error: 0.8983
# Epoch 36/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.5605 - mean_absolute_error: 0.5111 - val_loss: 0.3920 - val_mean_absolute_error: 0.4192
# Epoch 37/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.5378 - mean_absolute_error: 0.4808 - val_loss: 0.4567 - val_mean_absolute_error: 0.4921
# Epoch 38/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.5527 - mean_absolute_error: 0.5090 - val_loss: 0.3975 - val_mean_absolute_error: 0.4251
# Epoch 39/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5143 - mean_absolute_error: 0.4668 - val_loss: 0.3270 - val_mean_absolute_error: 0.3719
# Epoch 40/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5316 - mean_absolute_error: 0.4766 - val_loss: 0.4167 - val_mean_absolute_error: 0.4914
# Epoch 41/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.4942 - mean_absolute_error: 0.4513 - val_loss: 0.3829 - val_mean_absolute_error: 0.4122
# Epoch 42/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5492 - mean_absolute_error: 0.5045 - val_loss: 0.7216 - val_mean_absolute_error: 0.6984
# Epoch 43/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5152 - mean_absolute_error: 0.4752 - val_loss: 0.3767 - val_mean_absolute_error: 0.4167
# Epoch 44/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.4920 - mean_absolute_error: 0.4581 - val_loss: 0.3243 - val_mean_absolute_error: 0.3663
# Epoch 45/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5073 - mean_absolute_error: 0.4665 - val_loss: 0.5011 - val_mean_absolute_error: 0.5672
# Epoch 46/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5311 - mean_absolute_error: 0.4808 - val_loss: 0.3314 - val_mean_absolute_error: 0.3782
# Epoch 47/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5903 - mean_absolute_error: 0.5325 - val_loss: 0.3627 - val_mean_absolute_error: 0.3912
# Epoch 48/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5419 - mean_absolute_error: 0.4980 - val_loss: 0.3312 - val_mean_absolute_error: 0.3569
# Epoch 49/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.4848 - mean_absolute_error: 0.4556 - val_loss: 0.3732 - val_mean_absolute_error: 0.4509
# Epoch 50/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5303 - mean_absolute_error: 0.4917 - val_loss: 0.3859 - val_mean_absolute_error: 0.4656
# Epoch 51/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5015 - mean_absolute_error: 0.4645 - val_loss: 0.3360 - val_mean_absolute_error: 0.3612
# Epoch 52/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.6041 - mean_absolute_error: 0.5433 - val_loss: 0.3287 - val_mean_absolute_error: 0.3748
# Epoch 53/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5421 - mean_absolute_error: 0.4914 - val_loss: 0.3332 - val_mean_absolute_error: 0.3910
# Epoch 54/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5137 - mean_absolute_error: 0.4726 - val_loss: 0.4809 - val_mean_absolute_error: 0.5193
# Epoch 55/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.4928 - mean_absolute_error: 0.4632 - val_loss: 0.3526 - val_mean_absolute_error: 0.3794
# Epoch 56/100
# 57/57 [==============================] - 1s 14ms/step - loss: 0.5767 - mean_absolute_error: 0.5210 - val_loss: 0.3356 - val_mean_absolute_error: 0.3579
# Epoch 57/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.6521 - mean_absolute_error: 0.5651 - val_loss: 0.3273 - val_mean_absolute_error: 0.3565
# Epoch 58/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.6000 - mean_absolute_error: 0.5331 - val_loss: 0.3275 - val_mean_absolute_error: 0.3682
# Epoch 59/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5257 - mean_absolute_error: 0.4845 - val_loss: 0.3347 - val_mean_absolute_error: 0.3683
# Epoch 60/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5612 - mean_absolute_error: 0.5049 - val_loss: 0.3633 - val_mean_absolute_error: 0.4378
# Epoch 61/100
# 57/57 [==============================] - 1s 11ms/step - loss: 0.5717 - mean_absolute_error: 0.5072 - val_loss: 0.3523 - val_mean_absolute_error: 0.4156
# Epoch 62/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5596 - mean_absolute_error: 0.5012 - val_loss: 0.3491 - val_mean_absolute_error: 0.4216
# Epoch 63/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.6445 - mean_absolute_error: 0.5794 - val_loss: 0.3411 - val_mean_absolute_error: 0.3738
# Epoch 64/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5526 - mean_absolute_error: 0.4997 - val_loss: 0.3655 - val_mean_absolute_error: 0.3970
# Epoch 65/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.4942 - mean_absolute_error: 0.4588 - val_loss: 0.3920 - val_mean_absolute_error: 0.4715
# Epoch 66/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.6075 - mean_absolute_error: 0.5438 - val_loss: 0.3250 - val_mean_absolute_error: 0.3781
# Epoch 67/100
# 57/57 [==============================] - 1s 11ms/step - loss: 0.5184 - mean_absolute_error: 0.4815 - val_loss: 0.3329 - val_mean_absolute_error: 0.3973
# Epoch 68/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4951 - mean_absolute_error: 0.4589 - val_loss: 0.3210 - val_mean_absolute_error: 0.3759
# Epoch 69/100
# 57/57 [==============================] - 1s 11ms/step - loss: 0.6090 - mean_absolute_error: 0.5375 - val_loss: 0.4455 - val_mean_absolute_error: 0.5271
# Epoch 70/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.4812 - mean_absolute_error: 0.4415 - val_loss: 0.3687 - val_mean_absolute_error: 0.4056
# Epoch 71/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.6435 - mean_absolute_error: 0.5767 - val_loss: 0.4429 - val_mean_absolute_error: 0.4823
# Epoch 72/100
# 57/57 [==============================] - 1s 14ms/step - loss: 0.5713 - mean_absolute_error: 0.5143 - val_loss: 0.5129 - val_mean_absolute_error: 0.5828
# Epoch 73/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5921 - mean_absolute_error: 0.5443 - val_loss: 0.9886 - val_mean_absolute_error: 0.8852
# Epoch 74/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5699 - mean_absolute_error: 0.5123 - val_loss: 0.3691 - val_mean_absolute_error: 0.4477
# Epoch 75/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6752 - mean_absolute_error: 0.5938 - val_loss: 0.3280 - val_mean_absolute_error: 0.3902
# Epoch 76/100
# 57/57 [==============================] - 1s 11ms/step - loss: 0.5499 - mean_absolute_error: 0.4998 - val_loss: 0.3416 - val_mean_absolute_error: 0.3667
# Epoch 77/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.4786 - mean_absolute_error: 0.4457 - val_loss: 0.3329 - val_mean_absolute_error: 0.3739
# Epoch 78/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.4989 - mean_absolute_error: 0.4547 - val_loss: 0.6302 - val_mean_absolute_error: 0.6416
# Epoch 79/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5758 - mean_absolute_error: 0.5196 - val_loss: 0.3458 - val_mean_absolute_error: 0.3956
# Epoch 80/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5512 - mean_absolute_error: 0.4964 - val_loss: 0.3832 - val_mean_absolute_error: 0.4625
# Epoch 81/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6005 - mean_absolute_error: 0.5395 - val_loss: 0.3307 - val_mean_absolute_error: 0.3749
# Epoch 82/100
# 57/57 [==============================] - 1s 11ms/step - loss: 0.4856 - mean_absolute_error: 0.4442 - val_loss: 0.4436 - val_mean_absolute_error: 0.4859
# Epoch 83/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.6074 - mean_absolute_error: 0.5530 - val_loss: 0.3715 - val_mean_absolute_error: 0.4445
# Epoch 84/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5363 - mean_absolute_error: 0.4790 - val_loss: 0.3382 - val_mean_absolute_error: 0.4074
# Epoch 85/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.4956 - mean_absolute_error: 0.4604 - val_loss: 0.3352 - val_mean_absolute_error: 0.3624
# Epoch 86/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5208 - mean_absolute_error: 0.4776 - val_loss: 0.4676 - val_mean_absolute_error: 0.5084
# Epoch 87/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5332 - mean_absolute_error: 0.4818 - val_loss: 0.3538 - val_mean_absolute_error: 0.4191
# Epoch 88/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5128 - mean_absolute_error: 0.4726 - val_loss: 0.3510 - val_mean_absolute_error: 0.4266
# Epoch 89/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.6056 - mean_absolute_error: 0.5429 - val_loss: 0.3229 - val_mean_absolute_error: 0.3658
# Epoch 90/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5289 - mean_absolute_error: 0.4914 - val_loss: 0.3321 - val_mean_absolute_error: 0.3816
# Epoch 91/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.5306 - mean_absolute_error: 0.4884 - val_loss: 0.3219 - val_mean_absolute_error: 0.3589
# Epoch 92/100
# 57/57 [==============================] - 1s 11ms/step - loss: 0.4830 - mean_absolute_error: 0.4451 - val_loss: 0.3228 - val_mean_absolute_error: 0.3691
# Epoch 93/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.4799 - mean_absolute_error: 0.4388 - val_loss: 0.3464 - val_mean_absolute_error: 0.3714
# Epoch 94/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.4990 - mean_absolute_error: 0.4665 - val_loss: 0.4807 - val_mean_absolute_error: 0.5195
# Epoch 95/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.4805 - mean_absolute_error: 0.4458 - val_loss: 0.3712 - val_mean_absolute_error: 0.4050
# Epoch 96/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.7453 - mean_absolute_error: 0.6405 - val_loss: 0.4285 - val_mean_absolute_error: 0.4672
# Epoch 97/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.7249 - mean_absolute_error: 0.6351 - val_loss: 0.4596 - val_mean_absolute_error: 0.5353
# Epoch 98/100
# 57/57 [==============================] - 1s 12ms/step - loss: 0.6291 - mean_absolute_error: 0.5497 - val_loss: 0.3295 - val_mean_absolute_error: 0.3643
# Epoch 99/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5611 - mean_absolute_error: 0.5029 - val_loss: 0.4271 - val_mean_absolute_error: 0.4663
# Epoch 100/100
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5656 - mean_absolute_error: 0.5140 - val_loss: 0.3587 - val_mean_absolute_error: 0.4328

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               66560
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 91,521
# Trainable params: 91,521
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])

# %%
results = model.evaluate(X_train, y_train)
# Out:
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5146 - mean_absolute_error: 0.5058

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.xticks(rotation = 45)
plt.legend(['Validation Predictions', 'Validation Observations'])

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.xticks(rotation = 45)
plt.legend(['Testing Predictions', 'Testing Observations'])

# %%
results = model.evaluate(X_test, y_test)
# Out:
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1985 - mean_absolute_error: 0.3604

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])
