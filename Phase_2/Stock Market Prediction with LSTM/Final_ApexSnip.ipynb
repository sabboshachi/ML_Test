# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ML/updated/ApexSpi_HistoricalPrices - ApexSpi_HistoricalPrices.csv')

# %%
df
# Out:
#             Date    Open    High     Low   Close         Volume
# 0     1997-07-08   16.60   16.60   16.60   16.60     399.999996
# 1     1997-07-17   19.00   19.00   19.00   19.00    2199.999978
# 2     1997-07-21   18.50   18.50   18.50   18.50    5199.999948
# 3     1997-07-22   18.57   18.57   18.57   18.57    2999.999970
# 4     1997-07-28   19.00   19.00   19.00   19.00    3999.999960
# ...          ...     ...     ...     ...     ...            ...
# 4157  2022-08-04  140.90  141.00  136.20  137.20   52458.000000
# 4158  2022-08-08  135.40  138.00  135.10  135.70   29619.000000
# 4159  2022-08-10  135.70  143.90  135.70  140.00  112135.000000
# 4160  2022-08-11  138.50  140.20  136.60  138.30   25455.000000
# 4161  2022-08-16  142.10  147.40  142.00  145.90  148106.000000
#
# [4162 rows x 6 columns]

# %%
df = df[['Date', 'Close']]
df.head(10)
# Out:
#          Date  Close
# 0  1997-07-08  16.60
# 1  1997-07-17  19.00
# 2  1997-07-21  18.50
# 3  1997-07-22  18.57
# 4  1997-07-28  19.00
# 5  1997-07-31  18.50
# 6  1997-08-05  19.02
# 7  1997-08-06  18.76
# 8  1997-08-11  17.47
# 9  1997-08-13  17.00

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1998-08-23')
datetime_object
# Out:
# datetime.datetime(1998, 8, 23, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Date']
# Out:
# 0      1997-07-08
# 1      1997-07-17
# 2      1997-07-21
# 3      1997-07-22
# 4      1997-07-28
#           ...
# 4157   2022-08-04
# 4158   2022-08-08
# 4159   2022-08-10
# 4160   2022-08-11
# 4161   2022-08-16
# Name: Date, Length: 4162, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')

# %%
df.index
# Out:
# DatetimeIndex(['1997-07-08', '1997-07-17', '1997-07-21', '1997-07-22',
#                '1997-07-28', '1997-07-31', '1997-08-05', '1997-08-06',
#                '1997-08-11', '1997-08-13',
#                ...
#                '2022-07-27', '2022-07-28', '2022-08-01', '2022-08-02',
#                '2022-08-03', '2022-08-04', '2022-08-08', '2022-08-10',
#                '2022-08-11', '2022-08-16'],
#               dtype='datetime64[ns]', name='Date', length=4162, freq=None)

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  #print(target_date)
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+2)
    #print(df_subset)
    
    if len(df_subset) != n+2:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=100)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n+1):
    X[:, i]
    ret_df[f'Target-{n+1-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# %%
# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '1998-08-23', 
                                '2022-08-11',                         
                                n=5)
windowed_df
# Out:
#      Target Date  Target-6  Target-5  Target-4  Target-3  Target-2  Target-1  \
# 0     1998-08-23     14.61     14.81     14.70     14.75     15.10     14.88
# 1     1998-08-26     14.70     14.75     15.10     14.88     13.80     13.60
# 2     1998-08-27     14.75     15.10     14.88     13.80     13.60     13.35
# 3     1998-09-01     15.10     14.88     13.80     13.60     13.35     13.70
# 4     1998-09-02     14.88     13.80     13.60     13.35     13.70     13.60
# ...          ...       ...       ...       ...       ...       ...       ...
# 4041  2022-08-03    133.70    131.60    130.20    128.30    133.40    144.30
# 4042  2022-08-04    131.60    130.20    128.30    133.40    144.30    139.80
# 4043  2022-08-08    130.20    128.30    133.40    144.30    139.80    137.20
# 4044  2022-08-10    128.30    133.40    144.30    139.80    137.20    135.70
# 4045  2022-08-11    133.40    144.30    139.80    137.20    135.70    140.00
#
#       Target
# 0      13.80
# 1      13.35
# 2      13.70
# 3      13.60
# 4      13.80
# ...      ...
# 4041  139.80
# 4042  137.20
# 4043  135.70
# 4044  140.00
# 4045  138.30
#
# [4046 rows x 8 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((4046,), (4046, 6, 1), (4046,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90,]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((6, 1)),
                    layers.LSTM(128),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', optimizer=Adam(learning_rate=0.001), metrics=['mean_absolute_error'])

# model.compile(
#     optimizer=Adam(learning_rate=0.001),
#     loss='mse',
#     metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 102/102 [==============================] - 4s 19ms/step - loss: 1811.1471 - mean_absolute_error: 25.0063 - val_loss: 14.7818 - val_mean_absolute_error: 2.8813
# Epoch 2/100
# 102/102 [==============================] - 1s 13ms/step - loss: 10.5261 - mean_absolute_error: 1.9875 - val_loss: 38.8845 - val_mean_absolute_error: 5.2086
# Epoch 3/100
# 102/102 [==============================] - 2s 16ms/step - loss: 10.0422 - mean_absolute_error: 1.9212 - val_loss: 75.5123 - val_mean_absolute_error: 7.9214
# Epoch 4/100
# 102/102 [==============================] - 2s 16ms/step - loss: 9.1597 - mean_absolute_error: 1.8171 - val_loss: 46.1873 - val_mean_absolute_error: 6.0545
# Epoch 5/100
# 102/102 [==============================] - 1s 11ms/step - loss: 10.6116 - mean_absolute_error: 2.0457 - val_loss: 13.3591 - val_mean_absolute_error: 2.5812
# Epoch 6/100
# 102/102 [==============================] - 1s 10ms/step - loss: 13.0491 - mean_absolute_error: 2.3036 - val_loss: 23.0264 - val_mean_absolute_error: 3.7498
# Epoch 7/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.5023 - mean_absolute_error: 1.8950 - val_loss: 17.8891 - val_mean_absolute_error: 3.1108
# Epoch 8/100
# 102/102 [==============================] - 1s 10ms/step - loss: 11.0670 - mean_absolute_error: 2.1218 - val_loss: 15.2584 - val_mean_absolute_error: 2.7967
# Epoch 9/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.2667 - mean_absolute_error: 1.8026 - val_loss: 15.3941 - val_mean_absolute_error: 2.8565
# Epoch 10/100
# 102/102 [==============================] - 1s 10ms/step - loss: 12.1046 - mean_absolute_error: 2.2255 - val_loss: 20.9267 - val_mean_absolute_error: 3.4676
# Epoch 11/100
# 102/102 [==============================] - 1s 10ms/step - loss: 11.7707 - mean_absolute_error: 2.1399 - val_loss: 13.5201 - val_mean_absolute_error: 2.5780
# Epoch 12/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.8393 - mean_absolute_error: 1.7693 - val_loss: 16.5467 - val_mean_absolute_error: 3.0769
# Epoch 13/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.1490 - mean_absolute_error: 1.8345 - val_loss: 14.1435 - val_mean_absolute_error: 2.7198
# Epoch 14/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.0061 - mean_absolute_error: 1.7353 - val_loss: 15.9691 - val_mean_absolute_error: 2.8602
# Epoch 15/100
# 102/102 [==============================] - 1s 10ms/step - loss: 10.9648 - mean_absolute_error: 2.0338 - val_loss: 20.3693 - val_mean_absolute_error: 3.3868
# Epoch 16/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.7916 - mean_absolute_error: 1.9482 - val_loss: 28.8291 - val_mean_absolute_error: 4.4150
# Epoch 17/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.1171 - mean_absolute_error: 1.8397 - val_loss: 15.7261 - val_mean_absolute_error: 3.0197
# Epoch 18/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.9804 - mean_absolute_error: 1.8073 - val_loss: 13.6313 - val_mean_absolute_error: 2.5929
# Epoch 19/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.5077 - mean_absolute_error: 1.9017 - val_loss: 16.7641 - val_mean_absolute_error: 2.9533
# Epoch 20/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.4280 - mean_absolute_error: 1.8969 - val_loss: 14.8784 - val_mean_absolute_error: 2.7058
# Epoch 21/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.4526 - mean_absolute_error: 1.6939 - val_loss: 18.1506 - val_mean_absolute_error: 3.1515
# Epoch 22/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.7958 - mean_absolute_error: 1.8884 - val_loss: 44.2263 - val_mean_absolute_error: 5.6832
# Epoch 23/100
# 102/102 [==============================] - 1s 10ms/step - loss: 10.1771 - mean_absolute_error: 1.9624 - val_loss: 18.7195 - val_mean_absolute_error: 3.2144
# Epoch 24/100
# 102/102 [==============================] - 1s 10ms/step - loss: 11.4087 - mean_absolute_error: 2.0969 - val_loss: 31.2914 - val_mean_absolute_error: 4.6166
# Epoch 25/100
# 102/102 [==============================] - 1s 10ms/step - loss: 10.0234 - mean_absolute_error: 1.9289 - val_loss: 35.9181 - val_mean_absolute_error: 5.2606
# Epoch 26/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.9109 - mean_absolute_error: 1.9161 - val_loss: 51.1160 - val_mean_absolute_error: 6.1990
# Epoch 27/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.8901 - mean_absolute_error: 1.9828 - val_loss: 120.8192 - val_mean_absolute_error: 10.2523
# Epoch 28/100
# 102/102 [==============================] - 1s 10ms/step - loss: 14.5234 - mean_absolute_error: 2.2821 - val_loss: 20.9581 - val_mean_absolute_error: 3.5982
# Epoch 29/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.6986 - mean_absolute_error: 1.8684 - val_loss: 40.4719 - val_mean_absolute_error: 5.4274
# Epoch 30/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.3969 - mean_absolute_error: 1.8711 - val_loss: 16.0827 - val_mean_absolute_error: 2.8750
# Epoch 31/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.4123 - mean_absolute_error: 1.8367 - val_loss: 20.5988 - val_mean_absolute_error: 3.4570
# Epoch 32/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.7371 - mean_absolute_error: 1.8783 - val_loss: 24.2358 - val_mean_absolute_error: 3.9394
# Epoch 33/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.2123 - mean_absolute_error: 1.8211 - val_loss: 15.6139 - val_mean_absolute_error: 2.9132
# Epoch 34/100
# 102/102 [==============================] - 1s 10ms/step - loss: 11.8578 - mean_absolute_error: 2.1659 - val_loss: 41.1425 - val_mean_absolute_error: 5.5003
# Epoch 35/100
# 102/102 [==============================] - 1s 10ms/step - loss: 10.3377 - mean_absolute_error: 1.9928 - val_loss: 13.6494 - val_mean_absolute_error: 2.5852
# Epoch 36/100
# 102/102 [==============================] - 1s 10ms/step - loss: 10.1110 - mean_absolute_error: 1.9203 - val_loss: 14.0672 - val_mean_absolute_error: 2.7506
# Epoch 37/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.5518 - mean_absolute_error: 1.7744 - val_loss: 16.0495 - val_mean_absolute_error: 3.0476
# Epoch 38/100
# 102/102 [==============================] - 1s 10ms/step - loss: 10.1584 - mean_absolute_error: 1.9916 - val_loss: 17.0540 - val_mean_absolute_error: 2.9817
# Epoch 39/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.1840 - mean_absolute_error: 1.6578 - val_loss: 27.2803 - val_mean_absolute_error: 4.4659
# Epoch 40/100
# 102/102 [==============================] - 1s 10ms/step - loss: 12.1194 - mean_absolute_error: 2.2005 - val_loss: 15.3873 - val_mean_absolute_error: 2.9643
# Epoch 41/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.4296 - mean_absolute_error: 1.8996 - val_loss: 26.4442 - val_mean_absolute_error: 4.3148
# Epoch 42/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.7720 - mean_absolute_error: 1.9090 - val_loss: 15.2966 - val_mean_absolute_error: 2.9178
# Epoch 43/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.4364 - mean_absolute_error: 1.8949 - val_loss: 18.8111 - val_mean_absolute_error: 3.2309
# Epoch 44/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.9261 - mean_absolute_error: 1.7560 - val_loss: 17.3931 - val_mean_absolute_error: 3.0543
# Epoch 45/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.8573 - mean_absolute_error: 1.8600 - val_loss: 22.7243 - val_mean_absolute_error: 3.8116
# Epoch 46/100
# 102/102 [==============================] - 1s 10ms/step - loss: 10.2466 - mean_absolute_error: 1.9323 - val_loss: 30.9167 - val_mean_absolute_error: 4.5251
# Epoch 47/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.6098 - mean_absolute_error: 1.8954 - val_loss: 17.2331 - val_mean_absolute_error: 3.2467
# Epoch 48/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.6782 - mean_absolute_error: 1.9019 - val_loss: 14.3293 - val_mean_absolute_error: 2.6098
# Epoch 49/100
# 102/102 [==============================] - 1s 10ms/step - loss: 10.1514 - mean_absolute_error: 1.9136 - val_loss: 14.2625 - val_mean_absolute_error: 2.7660
# Epoch 50/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.1961 - mean_absolute_error: 1.6772 - val_loss: 18.4284 - val_mean_absolute_error: 3.1687
# Epoch 51/100
# 102/102 [==============================] - 1s 10ms/step - loss: 10.8134 - mean_absolute_error: 1.9641 - val_loss: 14.8395 - val_mean_absolute_error: 2.7054
# Epoch 52/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.5350 - mean_absolute_error: 1.8182 - val_loss: 19.9117 - val_mean_absolute_error: 3.3706
# Epoch 53/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.2125 - mean_absolute_error: 1.8158 - val_loss: 57.2463 - val_mean_absolute_error: 6.9498
# Epoch 54/100
# 102/102 [==============================] - 1s 10ms/step - loss: 11.3460 - mean_absolute_error: 2.0680 - val_loss: 44.2497 - val_mean_absolute_error: 5.6385
# Epoch 55/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.7170 - mean_absolute_error: 1.7485 - val_loss: 21.3356 - val_mean_absolute_error: 3.4669
# Epoch 56/100
# 102/102 [==============================] - 1s 10ms/step - loss: 15.5757 - mean_absolute_error: 2.5320 - val_loss: 30.4634 - val_mean_absolute_error: 4.7551
# Epoch 57/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.6000 - mean_absolute_error: 1.7215 - val_loss: 14.0306 - val_mean_absolute_error: 2.7113
# Epoch 58/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.9766 - mean_absolute_error: 1.7874 - val_loss: 13.7168 - val_mean_absolute_error: 2.6646
# Epoch 59/100
# 102/102 [==============================] - 1s 10ms/step - loss: 10.2690 - mean_absolute_error: 1.9346 - val_loss: 31.3054 - val_mean_absolute_error: 4.7263
# Epoch 60/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.2886 - mean_absolute_error: 1.8307 - val_loss: 21.7980 - val_mean_absolute_error: 3.5630
# Epoch 61/100
# 102/102 [==============================] - 1s 10ms/step - loss: 10.1661 - mean_absolute_error: 1.9216 - val_loss: 18.3240 - val_mean_absolute_error: 3.1767
# Epoch 62/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.5747 - mean_absolute_error: 1.7031 - val_loss: 39.0517 - val_mean_absolute_error: 5.2477
# Epoch 63/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.9814 - mean_absolute_error: 1.8071 - val_loss: 14.5652 - val_mean_absolute_error: 2.6875
# Epoch 64/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.5309 - mean_absolute_error: 1.9026 - val_loss: 14.8409 - val_mean_absolute_error: 2.8025
# Epoch 65/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.8037 - mean_absolute_error: 1.8421 - val_loss: 36.4703 - val_mean_absolute_error: 5.1871
# Epoch 66/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.5740 - mean_absolute_error: 1.7665 - val_loss: 14.6323 - val_mean_absolute_error: 2.6887
# Epoch 67/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.7627 - mean_absolute_error: 1.8954 - val_loss: 15.5865 - val_mean_absolute_error: 3.0181
# Epoch 68/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.7786 - mean_absolute_error: 1.8718 - val_loss: 15.2132 - val_mean_absolute_error: 2.8010
# Epoch 69/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.1719 - mean_absolute_error: 1.8104 - val_loss: 15.3019 - val_mean_absolute_error: 2.8114
# Epoch 70/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.4415 - mean_absolute_error: 1.8313 - val_loss: 17.5472 - val_mean_absolute_error: 3.0792
# Epoch 71/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.4208 - mean_absolute_error: 1.8368 - val_loss: 14.7708 - val_mean_absolute_error: 2.7072
# Epoch 72/100
# 102/102 [==============================] - 1s 10ms/step - loss: 10.2291 - mean_absolute_error: 1.9331 - val_loss: 52.3511 - val_mean_absolute_error: 6.2898
# Epoch 73/100
# 102/102 [==============================] - 1s 10ms/step - loss: 10.1891 - mean_absolute_error: 1.9244 - val_loss: 43.0588 - val_mean_absolute_error: 5.7260
# Epoch 74/100
# 102/102 [==============================] - 1s 10ms/step - loss: 10.4533 - mean_absolute_error: 2.0077 - val_loss: 16.1365 - val_mean_absolute_error: 3.1006
# Epoch 75/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.7635 - mean_absolute_error: 1.7292 - val_loss: 21.1779 - val_mean_absolute_error: 3.6412
# Epoch 76/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.1738 - mean_absolute_error: 1.7771 - val_loss: 16.2591 - val_mean_absolute_error: 2.9864
# Epoch 77/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.3737 - mean_absolute_error: 1.6915 - val_loss: 23.4465 - val_mean_absolute_error: 3.6654
# Epoch 78/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.2498 - mean_absolute_error: 1.7739 - val_loss: 17.9329 - val_mean_absolute_error: 3.2662
# Epoch 79/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.3282 - mean_absolute_error: 1.8116 - val_loss: 13.8381 - val_mean_absolute_error: 2.6656
# Epoch 80/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.4661 - mean_absolute_error: 1.7142 - val_loss: 19.2745 - val_mean_absolute_error: 3.2748
# Epoch 81/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.1600 - mean_absolute_error: 1.7681 - val_loss: 13.5706 - val_mean_absolute_error: 2.6296
# Epoch 82/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.4903 - mean_absolute_error: 1.7116 - val_loss: 19.6065 - val_mean_absolute_error: 3.3230
# Epoch 83/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.8852 - mean_absolute_error: 1.7621 - val_loss: 22.5351 - val_mean_absolute_error: 3.6906
# Epoch 84/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.8799 - mean_absolute_error: 1.7818 - val_loss: 31.5814 - val_mean_absolute_error: 4.7731
# Epoch 85/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.2747 - mean_absolute_error: 1.8122 - val_loss: 15.5300 - val_mean_absolute_error: 2.9356
# Epoch 86/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.9197 - mean_absolute_error: 1.7590 - val_loss: 26.4178 - val_mean_absolute_error: 4.3292
# Epoch 87/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.7813 - mean_absolute_error: 1.7271 - val_loss: 14.1202 - val_mean_absolute_error: 2.6278
# Epoch 88/100
# 102/102 [==============================] - 1s 11ms/step - loss: 8.9973 - mean_absolute_error: 1.7886 - val_loss: 21.8293 - val_mean_absolute_error: 3.5863
# Epoch 89/100
# 102/102 [==============================] - 2s 16ms/step - loss: 9.6297 - mean_absolute_error: 1.8630 - val_loss: 13.7968 - val_mean_absolute_error: 2.5969
# Epoch 90/100
# 102/102 [==============================] - 2s 16ms/step - loss: 8.9876 - mean_absolute_error: 1.7535 - val_loss: 14.0516 - val_mean_absolute_error: 2.5956
# Epoch 91/100
# 102/102 [==============================] - 1s 14ms/step - loss: 10.5381 - mean_absolute_error: 2.0126 - val_loss: 19.6541 - val_mean_absolute_error: 3.3124
# Epoch 92/100
# 102/102 [==============================] - 1s 10ms/step - loss: 10.0504 - mean_absolute_error: 1.9221 - val_loss: 15.5443 - val_mean_absolute_error: 2.8093
# Epoch 93/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.7108 - mean_absolute_error: 1.7330 - val_loss: 17.2736 - val_mean_absolute_error: 3.1968
# Epoch 94/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.9333 - mean_absolute_error: 1.8707 - val_loss: 17.2060 - val_mean_absolute_error: 3.2565
# Epoch 95/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.9319 - mean_absolute_error: 1.7368 - val_loss: 14.0956 - val_mean_absolute_error: 2.6363
# Epoch 96/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.4324 - mean_absolute_error: 1.8449 - val_loss: 20.4978 - val_mean_absolute_error: 3.4612
# Epoch 97/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.0235 - mean_absolute_error: 1.7899 - val_loss: 19.4751 - val_mean_absolute_error: 3.5140
# Epoch 98/100
# 102/102 [==============================] - 1s 11ms/step - loss: 8.7533 - mean_absolute_error: 1.7386 - val_loss: 18.2460 - val_mean_absolute_error: 3.1477
# Epoch 99/100
# 102/102 [==============================] - 1s 10ms/step - loss: 9.0445 - mean_absolute_error: 1.8098 - val_loss: 14.1528 - val_mean_absolute_error: 2.6397
# Epoch 100/100
# 102/102 [==============================] - 1s 10ms/step - loss: 8.3888 - mean_absolute_error: 1.7115 - val_loss: 73.2633 - val_mean_absolute_error: 7.3837

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 128)               66560
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  dense_11 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 91,521
# Trainable params: 91,521
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])

# %%
results = model.evaluate(X_train, y_train)
# Out:
# 102/102 [==============================] - 0s 4ms/step - loss: 22.2382 - mean_absolute_error: 2.8448

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.xticks(rotation = 45)
plt.legend(['Validation Predictions', 'Validation Observations'])

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.xticks(rotation = 45)
plt.legend(['Testing Predictions', 'Testing Observations'])

# %%
results = model.evaluate(X_test, y_test)
# Out:
# 13/13 [==============================] - 0s 4ms/step - loss: 74.2627 - mean_absolute_error: 7.6686

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])
