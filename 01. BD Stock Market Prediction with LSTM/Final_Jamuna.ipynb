# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ML/updated/Jamuna_HistoricalPrices - Jamuna_HistoricalPrices.csv')

# %%
df
# Out:
#             Date    Open    High     Low   Close        Volume
# 0     2008-01-21  151.60  169.94  151.60  168.83  8.941935e+05
# 1     2008-01-22  163.01  173.20  146.95  148.74  5.663553e+05
# 2     2008-01-23  143.04  150.78  136.52  147.73  2.438420e+06
# 3     2008-01-24  150.78  150.78  142.59  145.16  7.514759e+06
# 4     2008-01-28  148.34  149.15  144.67  145.77  6.591119e+05
# ...          ...     ...     ...     ...     ...           ...
# 2755  2022-08-04  169.00  170.00  168.10  168.90  1.049000e+04
# 2756  2022-08-08  171.00  174.90  171.00  173.80  1.278700e+04
# 2757  2022-08-10  179.50  179.50  169.10  170.80  1.738800e+04
# 2758  2022-08-11  171.00  173.40  169.10  169.50  1.369100e+04
# 2759  2022-08-16  168.80  173.00  168.80  169.80  5.302000e+03
#
# [2760 rows x 6 columns]

# %%
df = df[['Date', 'Close']]
df.head(10)
# Out:
#          Date   Close
# 0  2008-01-21  168.83
# 1  2008-01-22  148.74
# 2  2008-01-23  147.73
# 3  2008-01-24  145.16
# 4  2008-01-28  145.77
# 5  2008-01-29  143.20
# 6  2008-01-30  139.53
# 7  2008-01-31  141.78
# 8  2008-02-04  139.49
# 9  2008-02-05  145.89

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('2008-01-31')
datetime_object
# Out:
# datetime.datetime(2008, 1, 31, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Date']
# Out:
# 0      2008-01-21
# 1      2008-01-22
# 2      2008-01-23
# 3      2008-01-24
# 4      2008-01-28
#           ...
# 2755   2022-08-04
# 2756   2022-08-08
# 2757   2022-08-10
# 2758   2022-08-11
# 2759   2022-08-16
# Name: Date, Length: 2760, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')

# %%
df.index
# Out:
# DatetimeIndex(['2008-01-21', '2008-01-22', '2008-01-23', '2008-01-24',
#                '2008-01-28', '2008-01-29', '2008-01-30', '2008-01-31',
#                '2008-02-04', '2008-02-05',
#                ...
#                '2022-07-27', '2022-07-28', '2022-08-01', '2022-08-02',
#                '2022-08-03', '2022-08-04', '2022-08-08', '2022-08-10',
#                '2022-08-11', '2022-08-16'],
#               dtype='datetime64[ns]', name='Date', length=2760, freq=None)

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  #print(target_date)
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+2)
    #print(df_subset)
    
    if len(df_subset) != n+2:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=100)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n+1):
    X[:, i]
    ret_df[f'Target-{n+1-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# %%
# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '2008-01-31', 
                                '2022-08-11',                         
                                n=5)
windowed_df
# Out:
#      Target Date  Target-6  Target-5  Target-4  Target-3  Target-2  Target-1  \
# 0     2008-01-31    148.74    147.73    145.16    145.77    143.20    139.53
# 1     2008-02-04    147.73    145.16    145.77    143.20    139.53    141.78
# 2     2008-02-05    145.16    145.77    143.20    139.53    141.78    139.49
# 3     2008-02-06    145.77    143.20    139.53    141.78    139.49    145.89
# 4     2008-02-07    143.20    139.53    141.78    139.49    145.89    150.01
# ...          ...       ...       ...       ...       ...       ...       ...
# 2747  2022-08-03    167.00    167.80    167.70    166.50    169.60    170.00
# 2748  2022-08-04    167.80    167.70    166.50    169.60    170.00    170.40
# 2749  2022-08-08    167.70    166.50    169.60    170.00    170.40    168.90
# 2750  2022-08-10    166.50    169.60    170.00    170.40    168.90    173.80
# 2751  2022-08-11    169.60    170.00    170.40    168.90    173.80    170.80
#
#       Target
# 0     141.78
# 1     139.49
# 2     145.89
# 3     150.01
# 4     148.30
# ...      ...
# 2747  170.40
# 2748  168.90
# 2749  173.80
# 2750  170.80
# 2751  169.50
#
# [2752 rows x 8 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((2752,), (2752, 6, 1), (2752,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90,]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((6, 1)),
                    layers.LSTM(128),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', optimizer=Adam(learning_rate=0.001), metrics=['mean_absolute_error'])

# model.compile(
#     optimizer=Adam(learning_rate=0.001),
#     loss='mse',
#     metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 69/69 [==============================] - 1s 10ms/step - loss: 17.0440 - mean_absolute_error: 2.9445 - val_loss: 6.8054 - val_mean_absolute_error: 1.6426
# Epoch 2/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.2082 - mean_absolute_error: 2.8317 - val_loss: 19.5924 - val_mean_absolute_error: 3.8670
# Epoch 3/100
# 69/69 [==============================] - 1s 10ms/step - loss: 18.3639 - mean_absolute_error: 3.0745 - val_loss: 7.5193 - val_mean_absolute_error: 1.8193
# Epoch 4/100
# 69/69 [==============================] - 1s 11ms/step - loss: 15.5783 - mean_absolute_error: 2.7765 - val_loss: 10.9618 - val_mean_absolute_error: 2.5468
# Epoch 5/100
# 69/69 [==============================] - 1s 11ms/step - loss: 17.6441 - mean_absolute_error: 3.0421 - val_loss: 7.7431 - val_mean_absolute_error: 1.8789
# Epoch 6/100
# 69/69 [==============================] - 1s 12ms/step - loss: 17.7141 - mean_absolute_error: 3.0120 - val_loss: 7.6061 - val_mean_absolute_error: 1.8545
# Epoch 7/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.2622 - mean_absolute_error: 2.6945 - val_loss: 13.9979 - val_mean_absolute_error: 3.0496
# Epoch 8/100
# 69/69 [==============================] - 1s 11ms/step - loss: 16.4418 - mean_absolute_error: 2.8268 - val_loss: 6.8415 - val_mean_absolute_error: 1.6507
# Epoch 9/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.2767 - mean_absolute_error: 2.7030 - val_loss: 6.5469 - val_mean_absolute_error: 1.5801
# Epoch 10/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.4134 - mean_absolute_error: 2.8697 - val_loss: 6.8902 - val_mean_absolute_error: 1.6846
# Epoch 11/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.2741 - mean_absolute_error: 2.8532 - val_loss: 8.1151 - val_mean_absolute_error: 1.9947
# Epoch 12/100
# 69/69 [==============================] - 1s 11ms/step - loss: 16.6622 - mean_absolute_error: 2.8811 - val_loss: 6.7223 - val_mean_absolute_error: 1.6196
# Epoch 13/100
# 69/69 [==============================] - 1s 10ms/step - loss: 14.7864 - mean_absolute_error: 2.6848 - val_loss: 7.5000 - val_mean_absolute_error: 1.8343
# Epoch 14/100
# 69/69 [==============================] - 1s 11ms/step - loss: 14.9698 - mean_absolute_error: 2.6790 - val_loss: 6.8870 - val_mean_absolute_error: 1.6704
# Epoch 15/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.2862 - mean_absolute_error: 2.7109 - val_loss: 8.3806 - val_mean_absolute_error: 2.0947
# Epoch 16/100
# 69/69 [==============================] - 1s 11ms/step - loss: 17.1963 - mean_absolute_error: 3.0081 - val_loss: 11.6168 - val_mean_absolute_error: 2.6513
# Epoch 17/100
# 69/69 [==============================] - 1s 10ms/step - loss: 17.3997 - mean_absolute_error: 3.0555 - val_loss: 8.7093 - val_mean_absolute_error: 2.1270
# Epoch 18/100
# 69/69 [==============================] - 1s 11ms/step - loss: 17.3442 - mean_absolute_error: 2.9826 - val_loss: 6.7695 - val_mean_absolute_error: 1.6331
# Epoch 19/100
# 69/69 [==============================] - 1s 18ms/step - loss: 16.9016 - mean_absolute_error: 2.9128 - val_loss: 10.6108 - val_mean_absolute_error: 2.4990
# Epoch 20/100
# 69/69 [==============================] - 1s 20ms/step - loss: 16.4798 - mean_absolute_error: 2.9280 - val_loss: 6.8798 - val_mean_absolute_error: 1.6639
# Epoch 21/100
# 69/69 [==============================] - 1s 11ms/step - loss: 14.5861 - mean_absolute_error: 2.6016 - val_loss: 7.8207 - val_mean_absolute_error: 1.9138
# Epoch 22/100
# 69/69 [==============================] - 1s 13ms/step - loss: 16.8069 - mean_absolute_error: 2.9247 - val_loss: 6.9963 - val_mean_absolute_error: 1.6932
# Epoch 23/100
# 69/69 [==============================] - 1s 11ms/step - loss: 15.3761 - mean_absolute_error: 2.7402 - val_loss: 7.6480 - val_mean_absolute_error: 1.9012
# Epoch 24/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.0523 - mean_absolute_error: 2.7834 - val_loss: 10.4439 - val_mean_absolute_error: 2.4639
# Epoch 25/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.5054 - mean_absolute_error: 2.8002 - val_loss: 14.0905 - val_mean_absolute_error: 3.0716
# Epoch 26/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.2707 - mean_absolute_error: 2.8988 - val_loss: 8.5594 - val_mean_absolute_error: 2.1412
# Epoch 27/100
# 69/69 [==============================] - 1s 10ms/step - loss: 17.0010 - mean_absolute_error: 2.9687 - val_loss: 11.5545 - val_mean_absolute_error: 2.6366
# Epoch 28/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.2377 - mean_absolute_error: 2.8353 - val_loss: 13.7412 - val_mean_absolute_error: 3.0682
# Epoch 29/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.7627 - mean_absolute_error: 2.7806 - val_loss: 6.8878 - val_mean_absolute_error: 1.6656
# Epoch 30/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.0199 - mean_absolute_error: 2.8073 - val_loss: 7.9453 - val_mean_absolute_error: 1.9347
# Epoch 31/100
# 69/69 [==============================] - 1s 10ms/step - loss: 20.7883 - mean_absolute_error: 3.4147 - val_loss: 12.1489 - val_mean_absolute_error: 2.7730
# Epoch 32/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.8574 - mean_absolute_error: 2.9249 - val_loss: 11.0300 - val_mean_absolute_error: 2.5814
# Epoch 33/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.7444 - mean_absolute_error: 2.8078 - val_loss: 11.9176 - val_mean_absolute_error: 2.7732
# Epoch 34/100
# 69/69 [==============================] - 1s 10ms/step - loss: 17.3595 - mean_absolute_error: 2.9692 - val_loss: 6.9789 - val_mean_absolute_error: 1.7212
# Epoch 35/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.3666 - mean_absolute_error: 2.7434 - val_loss: 10.0260 - val_mean_absolute_error: 2.4193
# Epoch 36/100
# 69/69 [==============================] - 1s 10ms/step - loss: 18.3106 - mean_absolute_error: 3.1714 - val_loss: 7.8208 - val_mean_absolute_error: 1.9663
# Epoch 37/100
# 69/69 [==============================] - 1s 10ms/step - loss: 20.0461 - mean_absolute_error: 3.2988 - val_loss: 13.7161 - val_mean_absolute_error: 3.0064
# Epoch 38/100
# 69/69 [==============================] - 1s 10ms/step - loss: 24.2576 - mean_absolute_error: 3.7899 - val_loss: 6.7860 - val_mean_absolute_error: 1.6426
# Epoch 39/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.8004 - mean_absolute_error: 2.9262 - val_loss: 6.5855 - val_mean_absolute_error: 1.6193
# Epoch 40/100
# 69/69 [==============================] - 1s 10ms/step - loss: 17.4130 - mean_absolute_error: 3.0093 - val_loss: 6.6293 - val_mean_absolute_error: 1.6145
# Epoch 41/100
# 69/69 [==============================] - 1s 10ms/step - loss: 19.3832 - mean_absolute_error: 3.2202 - val_loss: 6.6806 - val_mean_absolute_error: 1.6147
# Epoch 42/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.6783 - mean_absolute_error: 2.8938 - val_loss: 10.0278 - val_mean_absolute_error: 2.3743
# Epoch 43/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.6028 - mean_absolute_error: 2.9330 - val_loss: 7.9904 - val_mean_absolute_error: 1.9551
# Epoch 44/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.9266 - mean_absolute_error: 2.8240 - val_loss: 8.2365 - val_mean_absolute_error: 2.0794
# Epoch 45/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.4287 - mean_absolute_error: 2.7469 - val_loss: 6.7592 - val_mean_absolute_error: 1.6451
# Epoch 46/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.1638 - mean_absolute_error: 2.8765 - val_loss: 7.5744 - val_mean_absolute_error: 1.8524
# Epoch 47/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.7131 - mean_absolute_error: 2.7819 - val_loss: 7.5149 - val_mean_absolute_error: 1.8453
# Epoch 48/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.5656 - mean_absolute_error: 2.9362 - val_loss: 12.6871 - val_mean_absolute_error: 2.8586
# Epoch 49/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.7583 - mean_absolute_error: 2.7862 - val_loss: 7.0786 - val_mean_absolute_error: 1.7343
# Epoch 50/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.1408 - mean_absolute_error: 2.6944 - val_loss: 9.0501 - val_mean_absolute_error: 2.2566
# Epoch 51/100
# 69/69 [==============================] - 1s 11ms/step - loss: 17.0688 - mean_absolute_error: 2.9396 - val_loss: 14.9682 - val_mean_absolute_error: 3.2360
# Epoch 52/100
# 69/69 [==============================] - 1s 10ms/step - loss: 19.9424 - mean_absolute_error: 3.2867 - val_loss: 8.8683 - val_mean_absolute_error: 2.1613
# Epoch 53/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.4297 - mean_absolute_error: 2.9149 - val_loss: 13.3623 - val_mean_absolute_error: 2.9772
# Epoch 54/100
# 69/69 [==============================] - 1s 10ms/step - loss: 18.0748 - mean_absolute_error: 3.0890 - val_loss: 18.1080 - val_mean_absolute_error: 3.6781
# Epoch 55/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.4972 - mean_absolute_error: 2.9087 - val_loss: 7.2861 - val_mean_absolute_error: 1.7849
# Epoch 56/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.8502 - mean_absolute_error: 2.7805 - val_loss: 8.2937 - val_mean_absolute_error: 2.0141
# Epoch 57/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.3313 - mean_absolute_error: 2.7631 - val_loss: 15.8086 - val_mean_absolute_error: 3.3752
# Epoch 58/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.0758 - mean_absolute_error: 2.8460 - val_loss: 6.8054 - val_mean_absolute_error: 1.6411
# Epoch 59/100
# 69/69 [==============================] - 1s 10ms/step - loss: 14.5672 - mean_absolute_error: 2.6011 - val_loss: 12.4743 - val_mean_absolute_error: 2.8582
# Epoch 60/100
# 69/69 [==============================] - 1s 10ms/step - loss: 17.8872 - mean_absolute_error: 3.0766 - val_loss: 15.3424 - val_mean_absolute_error: 3.2943
# Epoch 61/100
# 69/69 [==============================] - 1s 10ms/step - loss: 20.9643 - mean_absolute_error: 3.4310 - val_loss: 6.7405 - val_mean_absolute_error: 1.6278
# Epoch 62/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.5047 - mean_absolute_error: 2.8895 - val_loss: 12.7057 - val_mean_absolute_error: 2.9010
# Epoch 63/100
# 69/69 [==============================] - 1s 10ms/step - loss: 18.9138 - mean_absolute_error: 3.1325 - val_loss: 11.1291 - val_mean_absolute_error: 2.6458
# Epoch 64/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.1017 - mean_absolute_error: 2.8519 - val_loss: 9.3631 - val_mean_absolute_error: 2.2594
# Epoch 65/100
# 69/69 [==============================] - 1s 11ms/step - loss: 18.0409 - mean_absolute_error: 3.0863 - val_loss: 10.6760 - val_mean_absolute_error: 2.5288
# Epoch 66/100
# 69/69 [==============================] - 1s 11ms/step - loss: 16.5332 - mean_absolute_error: 2.9172 - val_loss: 6.8516 - val_mean_absolute_error: 1.6570
# Epoch 67/100
# 69/69 [==============================] - 1s 10ms/step - loss: 14.8320 - mean_absolute_error: 2.6642 - val_loss: 6.8785 - val_mean_absolute_error: 1.6609
# Epoch 68/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.1694 - mean_absolute_error: 2.6992 - val_loss: 7.1244 - val_mean_absolute_error: 1.7444
# Epoch 69/100
# 69/69 [==============================] - 1s 10ms/step - loss: 17.5414 - mean_absolute_error: 2.9935 - val_loss: 13.5324 - val_mean_absolute_error: 3.0199
# Epoch 70/100
# 69/69 [==============================] - 1s 10ms/step - loss: 18.4380 - mean_absolute_error: 3.1953 - val_loss: 9.3361 - val_mean_absolute_error: 2.3110
# Epoch 71/100
# 69/69 [==============================] - 1s 10ms/step - loss: 14.9678 - mean_absolute_error: 2.7044 - val_loss: 7.1249 - val_mean_absolute_error: 1.7392
# Epoch 72/100
# 69/69 [==============================] - 1s 11ms/step - loss: 16.4506 - mean_absolute_error: 2.9011 - val_loss: 11.6207 - val_mean_absolute_error: 2.6879
# Epoch 73/100
# 69/69 [==============================] - 1s 14ms/step - loss: 17.7428 - mean_absolute_error: 3.0844 - val_loss: 7.0322 - val_mean_absolute_error: 1.7074
# Epoch 74/100
# 69/69 [==============================] - 1s 16ms/step - loss: 15.1831 - mean_absolute_error: 2.7412 - val_loss: 6.6039 - val_mean_absolute_error: 1.6533
# Epoch 75/100
# 69/69 [==============================] - 1s 17ms/step - loss: 17.0449 - mean_absolute_error: 3.0145 - val_loss: 7.2618 - val_mean_absolute_error: 1.8041
# Epoch 76/100
# 69/69 [==============================] - 1s 16ms/step - loss: 24.0642 - mean_absolute_error: 3.7703 - val_loss: 14.9321 - val_mean_absolute_error: 3.1947
# Epoch 77/100
# 69/69 [==============================] - 1s 12ms/step - loss: 15.8706 - mean_absolute_error: 2.8367 - val_loss: 7.7097 - val_mean_absolute_error: 1.8879
# Epoch 78/100
# 69/69 [==============================] - 1s 11ms/step - loss: 14.8775 - mean_absolute_error: 2.6613 - val_loss: 7.6018 - val_mean_absolute_error: 1.8484
# Epoch 79/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.4081 - mean_absolute_error: 2.7264 - val_loss: 9.4258 - val_mean_absolute_error: 2.2631
# Epoch 80/100
# 69/69 [==============================] - 1s 10ms/step - loss: 20.2565 - mean_absolute_error: 3.2890 - val_loss: 7.8331 - val_mean_absolute_error: 1.9155
# Epoch 81/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.7345 - mean_absolute_error: 2.7737 - val_loss: 7.9199 - val_mean_absolute_error: 1.9798
# Epoch 82/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.2585 - mean_absolute_error: 2.7287 - val_loss: 8.5739 - val_mean_absolute_error: 2.0845
# Epoch 83/100
# 69/69 [==============================] - 1s 11ms/step - loss: 15.9894 - mean_absolute_error: 2.8244 - val_loss: 12.5452 - val_mean_absolute_error: 2.8810
# Epoch 84/100
# 69/69 [==============================] - 1s 11ms/step - loss: 15.8883 - mean_absolute_error: 2.8280 - val_loss: 23.6774 - val_mean_absolute_error: 4.3243
# Epoch 85/100
# 69/69 [==============================] - 1s 10ms/step - loss: 17.7679 - mean_absolute_error: 3.0631 - val_loss: 6.9746 - val_mean_absolute_error: 1.7075
# Epoch 86/100
# 69/69 [==============================] - 1s 10ms/step - loss: 14.2201 - mean_absolute_error: 2.5971 - val_loss: 11.4265 - val_mean_absolute_error: 2.6943
# Epoch 87/100
# 69/69 [==============================] - 1s 11ms/step - loss: 15.8305 - mean_absolute_error: 2.8220 - val_loss: 7.4170 - val_mean_absolute_error: 1.8520
# Epoch 88/100
# 69/69 [==============================] - 1s 10ms/step - loss: 17.0392 - mean_absolute_error: 2.9674 - val_loss: 6.6295 - val_mean_absolute_error: 1.6032
# Epoch 89/100
# 69/69 [==============================] - 1s 10ms/step - loss: 18.6235 - mean_absolute_error: 3.1755 - val_loss: 12.7206 - val_mean_absolute_error: 2.9133
# Epoch 90/100
# 69/69 [==============================] - 1s 10ms/step - loss: 17.6621 - mean_absolute_error: 3.0392 - val_loss: 8.4196 - val_mean_absolute_error: 2.1053
# Epoch 91/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.6038 - mean_absolute_error: 2.7918 - val_loss: 7.0891 - val_mean_absolute_error: 1.7345
# Epoch 92/100
# 69/69 [==============================] - 1s 10ms/step - loss: 15.8323 - mean_absolute_error: 2.8197 - val_loss: 6.6845 - val_mean_absolute_error: 1.6164
# Epoch 93/100
# 69/69 [==============================] - 1s 11ms/step - loss: 14.7980 - mean_absolute_error: 2.6525 - val_loss: 7.2328 - val_mean_absolute_error: 1.7885
# Epoch 94/100
# 69/69 [==============================] - 1s 10ms/step - loss: 14.8303 - mean_absolute_error: 2.6589 - val_loss: 14.9409 - val_mean_absolute_error: 3.2349
# Epoch 95/100
# 69/69 [==============================] - 1s 10ms/step - loss: 14.7088 - mean_absolute_error: 2.6734 - val_loss: 7.1808 - val_mean_absolute_error: 1.7737
# Epoch 96/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.9246 - mean_absolute_error: 2.9460 - val_loss: 6.6105 - val_mean_absolute_error: 1.5807
# Epoch 97/100
# 69/69 [==============================] - 1s 17ms/step - loss: 18.0459 - mean_absolute_error: 3.1067 - val_loss: 27.3147 - val_mean_absolute_error: 4.7059
# Epoch 98/100
# 69/69 [==============================] - 1s 11ms/step - loss: 16.4412 - mean_absolute_error: 2.8503 - val_loss: 9.3798 - val_mean_absolute_error: 2.2683
# Epoch 99/100
# 69/69 [==============================] - 1s 11ms/step - loss: 19.2859 - mean_absolute_error: 3.2275 - val_loss: 11.8548 - val_mean_absolute_error: 2.7521
# Epoch 100/100
# 69/69 [==============================] - 1s 10ms/step - loss: 16.2534 - mean_absolute_error: 2.8148 - val_loss: 20.6324 - val_mean_absolute_error: 3.9662

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               66560
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 91,521
# Trainable params: 91,521
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])

# %%
results = model.evaluate(X_train, y_train)
# Out:
# 69/69 [==============================] - 0s 4ms/step - loss: 26.7686 - mean_absolute_error: 4.3117

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.xticks(rotation = 45)
plt.legend(['Validation Predictions', 'Validation Observations'])

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.xticks(rotation = 45)
plt.legend(['Testing Predictions', 'Testing Observations'])

# %%
results = model.evaluate(X_test, y_test)
# Out:
# 9/9 [==============================] - 0s 6ms/step - loss: 19.3494 - mean_absolute_error: 4.0155

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])
